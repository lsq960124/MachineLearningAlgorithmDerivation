# %% [markdown]
# # 自然语言处理
# ## 词袋模型的使用
# 本节将使用词袋模型来进行垃圾短信的预测

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import numpy as np
import csv
import string
import requests
import io
from zipfile import ZipFile
from tensorflow.contrib import learn
from tensorflow.python.framework import ops
ops.reset_default_graph()
sess = tf.Session()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ### 下载数据集，保存到本地<p>
# 逻辑：
# 1. 判断数据集文件夹是否存在，不存在则创建
# 2. 判断文件是否存在，存在则读取，不存在则下载

# %%
save_file_name = os.path.join('temp','temp_spam_data.csv')

# Create directory if it doesn't exist
if not os.path.exists('temp'):
    os.makedirs('temp')

if os.path.isfile(save_file_name):
    text_data = []
    with open(save_file_name, 'r',newline='') as temp_output_file:
        reader = csv.reader(temp_output_file)
        for row in reader:
            text_data.append(row)
else:
    zip_url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/00228/smsspamcollection.zip'
    r = requests.get(zip_url)
    z = ZipFile(io.BytesIO(r.content))
    file = z.read('SMSSpamCollection')
    # Format Data
    text_data = file.decode()
    text_data = text_data.encode('ascii',errors='ignore')
    text_data = text_data.decode().split('\n')
    text_data = [x.split('\t') for x in text_data if len(x)>=1]
    
    # And write to csv
    with open(save_file_name, 'w',newline='') as temp_output_file:
        writer = csv.writer(temp_output_file)
        writer.writerows(text_data)

texts = [x[1] for x in text_data]
target = [x[0] for x in text_data]

# %% [markdown]
# 数据预处理
# 1. 将垃圾邮件（spam）标记为1，将非垃圾文件标记为0
# 2. 统一大小写
# 3. 去掉标点符号
# 4. 去掉数字

# %%
target = [1 if x=='spam' else 0 for x in target]

# Normalize text
texts = [x.lower() for x in texts]
texts = [''.join(c for c in x if c not in string.punctuation) for x in texts]
texts = [''.join(c for c in x if c not in '0123456789') for x in texts]

texts = [' '.join(x.split()) for x in texts]

# %% [markdown]
# * 文本长度直方图，来选取最佳截止点

# %%
text_lengths = [len(x.split()) for x in texts]
text_lengths = [x for x in text_lengths if x < 50]
plt.hist(text_lengths, bins=25)
plt.title('Histogram of lenght of Words in Texts')
plt.show()

# %% [markdown]
# 从数据分布直方图可以看出，大部分的文本长度在8-30之间。我们可以选择30作为最佳文本的截取长度，同时我们也舍弃出现频次低的文本（frec=3）

# %%
sentence_size = 25
min_word_freq = 3

# %% [markdown]
# 使用TensorFlow自带的分词器来分词

# %%
vocab_processor = learn.preprocessing.VocabularyProcessor(sentence_size, min_frequency=min_word_freq)

vocab_processor.transform(texts)
transformed_texts = np.array([x for x in vocab_processor.transform(texts)])

embedding_size = len(np.unique(transformed_texts))
# Out:
# WARNING:tensorflow:From <ipython-input-6-e54eef85f63a>:1: VocabularyProcessor.__init__ (from tensorflow.contrib.learn.python.learn.preprocessing.text) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tensorflow/transform or tf.data.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\preprocessing\text.py:154: CategoricalVocabulary.__init__ (from tensorflow.contrib.learn.python.learn.preprocessing.categorical_vocabulary) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tensorflow/transform or tf.data.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\preprocessing\text.py:203: tokenizer (from tensorflow.contrib.learn.python.learn.preprocessing.text) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tensorflow/transform or tf.data.

# %% [markdown]
# 可视化数据处理后的数据及文本分布直方图

# %%
print('词嵌入数据')
print(transformed_texts)
text_lengths = [len(x) for x in transformed_texts]
text_lengths = [x for x in text_lengths if x < 50]
plt.hist(text_lengths, bins=25)
plt.title('Histogram of lenght of Words in Texts')
plt.show()
# Out:
# 词嵌入数据
# [[   1    2    3 ...    0    0    0]
#  [  21   22   23 ...    0    0    0]
#  [  27   28    8 ...   44   45   46]
#  ...
#  [8161  328    8 ...    0    0    0]
#  [ 141 2552  224 ...   32  887   83]
#  [3379   69 1245 ...    0    0    0]]

# %% [markdown]
# 分割数据集。80% train 和 20% test

# %%
train_indices = np.random.choice(len(texts), round(len(texts)*0.8), replace=False)
test_indices = np.array(list(set(range(len(texts))) - set(train_indices)))
texts_train = [x for ix, x in enumerate(texts) if ix in train_indices]
texts_test = [x for ix, x in enumerate(texts) if ix in test_indices]
target_train = [x for ix, x in enumerate(target) if ix in train_indices]
target_test = [x for ix, x in enumerate(target) if ix in test_indices]

# %% [markdown]
# 声明词嵌入矩阵，
# 1. 将矩阵单词转化成索引
# 2. 再将索引转化成one-hot向量

# %%
identity_mat = tf.diag(tf.ones(shape=[embedding_size]))

# %% [markdown]
# 使用LR来预测垃圾短信

# %%
w = tf.Variable(tf.random_normal(shape=[embedding_size,1]))
b = tf.Variable(tf.random_normal(shape=[1,1]))

x_data = tf.placeholder(shape=[sentence_size], dtype=tf.int32)
y_target = tf.placeholder(shape=[1, 1], dtype=tf.float32)

# %% [markdown]
# 使用TensorFlow的词嵌入查找函数来映射句子中的单词为单位矩阵的one-hot向量。然后把前面的词向量求和

# %%
x_embed = tf.nn.embedding_lookup(identity_mat, x_data)
x_col_sums = tf.reduce_sum(x_embed, 0)

x_col_sums_2D = tf.expand_dims(x_col_sums, 0)
model_output = tf.add(tf.matmul(x_col_sums_2D, w), b)

# %%
# Declare loss function (Cross Entropy loss)
loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=model_output, labels=y_target))

prediction = tf.sigmoid(model_output)

my_opt = tf.train.GradientDescentOptimizer(0.001)
train_step = my_opt.minimize(loss)

init = tf.global_variables_initializer()
sess.run(init)

# %%
print('开始训练，总计 {} 条数据.'.format(len(texts_train)))
loss_vec = []
train_acc_all = []
train_acc_avg = []
for ix, t in enumerate(vocab_processor.fit_transform(texts_train)):
    y_data = [[target_train[ix]]]
    
    sess.run(train_step, feed_dict={x_data: t, y_target: y_data})
    temp_loss = sess.run(loss, feed_dict={x_data: t, y_target: y_data})
    loss_vec.append(temp_loss)
    
    if (ix+1)%10==0:
        print('epoch #' + str(ix+1) + ': Loss = ' + str(temp_loss))

    [[temp_pred]] = sess.run(prediction, feed_dict={x_data:t, y_target:y_data})
    train_acc_temp = target_train[ix]==np.round(temp_pred)
    train_acc_all.append(train_acc_temp)
    if len(train_acc_all) >= 50:
        train_acc_avg.append(np.mean(train_acc_all[-50:]))
# Out:
# 开始训练，总计 4459 条数据.
# epoch #10: Loss = 0.021336155
# epoch #20: Loss = 4.0811755e-12
# epoch #30: Loss = 0.00046681328
# epoch #40: Loss = 1.3996621e-12
# epoch #50: Loss = 0.28140402
# epoch #60: Loss = 4.842244e-13
# epoch #70: Loss = 4.5894204e-12
# epoch #80: Loss = 0.0044423128
# epoch #90: Loss = 8.980637
# epoch #100: Loss = 0.91449845
# epoch #110: Loss = 3.2358763e-14
# epoch #120: Loss = 1.5286904e-12
# epoch #130: Loss = 1.833588e-13
# epoch #140: Loss = 6.406382e-10
# epoch #150: Loss = 5.598185
# epoch #160: Loss = 21.989618
# epoch #170: Loss = 5.1302444e-14
# epoch #180: Loss = 2.5553377e-12
# epoch #190: Loss = 13.282319
# epoch #200: Loss = 7.257458e-10
# epoch #210: Loss = 2.6430334e-12
# epoch #220: Loss = 5.6136025e-12
# epoch #230: Loss = 4.2072995e-15
# epoch #240: Loss = 8.7910365e-07
# epoch #250: Loss = 9.346302e-09
# epoch #260: Loss = 14.931489
# epoch #270: Loss = 1.0426993e-05
# epoch #280: Loss = 12.373794
# epoch #290: Loss = 6.932757e-09
# epoch #300: Loss = 5.727739e-12
# epoch #310: Loss = 2.3507893
# epoch #320: Loss = 2.355319e-11
# epoch #330: Loss = 0.3043232
# epoch #340: Loss = 6.966813e-08
# epoch #350: Loss = 2.4502457e-12
# epoch #360: Loss = 1.4644843e-13
# epoch #370: Loss = 2.5745212e-11
# epoch #380: Loss = 4.307825e-09
# epoch #390: Loss = 9.742966
# epoch #400: Loss = 6.2559576e-07
# epoch #410: Loss = 4.090352e-06
# epoch #420: Loss = 2.4544521e-11
# epoch #430: Loss = 3.3749524e-11
# epoch #440: Loss = 2.4575634e-06
# epoch #450: Loss = 3.2014638e-12
# epoch #460: Loss = 4.174891e-12
# epoch #470: Loss = 4.509463e-11
# epoch #480: Loss = 0.0065194913
# epoch #490: Loss = 1.7280522e-08
# epoch #500: Loss = 1.8298934e-11
# epoch #510: Loss = 0.02905952
# epoch #520: Loss = 2.7796174e-09
# epoch #530: Loss = 11.51869
# epoch #540: Loss = 7.65519e-10
# epoch #550: Loss = 0.050519828
# epoch #560: Loss = 2.8190594e-12
# epoch #570: Loss = 2.0429605e-10
# epoch #580: Loss = 26.31251
# epoch #590: Loss = 7.2027857e-12
# epoch #600: Loss = 6.149595e-07
# epoch #610: Loss = 1.2562504e-06
# epoch #620: Loss = 3.5366854e-10
# epoch #630: Loss = 0.32052502
# epoch #640: Loss = 4.2193347e-09
# epoch #650: Loss = 1.9764423e-09
# epoch #660: Loss = 7.921871e-08
# epoch #670: Loss = 3.6790834e-06
# epoch #680: Loss = 3.257827
# epoch #690: Loss = 0.00043463398
# epoch #700: Loss = 9.562374e-10
# epoch #710: Loss = 8.5188404e-08
# epoch #720: Loss = 3.8476496e-06
# epoch #730: Loss = 2.241473e-06
# epoch #740: Loss = 5.160963
# epoch #750: Loss = 3.1106022e-09
# epoch #760: Loss = 1.2469699
# epoch #770: Loss = 4.606296e-05
# epoch #780: Loss = 3.4712014
# epoch #790: Loss = 5.579385
# epoch #800: Loss = 2.530559e-07
# epoch #810: Loss = 0.00040277455
# epoch #820: Loss = 1.1401274
# epoch #830: Loss = 1.1651828e-07
# epoch #840: Loss = 1.4530324e-09
# epoch #850: Loss = 4.3874774e-05
# epoch #860: Loss = 7.2189627
# epoch #870: Loss = 3.1533837
# epoch #880: Loss = 0.014899439
# epoch #890: Loss = 5.5514544e-11
# epoch #900: Loss = 0.02700623
# epoch #910: Loss = 1.2997636e-07
# epoch #920: Loss = 5.1461015
# epoch #930: Loss = 5.6258773e-07
# epoch #940: Loss = 1.9918773
# epoch #950: Loss = 2.7528824e-05
# epoch #960: Loss = 1.0511056e-08
# epoch #970: Loss = 1.9413049e-08
# epoch #980: Loss = 0.00011636312
# epoch #990: Loss = 1.6575748
# epoch #1000: Loss = 1.2491434e-07
# epoch #1010: Loss = 0.7725328
# epoch #1020: Loss = 0.0003429552
# epoch #1030: Loss = 15.803673
# epoch #1040: Loss = 3.3844668e-07
# epoch #1050: Loss = 1.6516701e-08
# epoch #1060: Loss = 5.562773e-06
# epoch #1070: Loss = 6.132112e-08
# epoch #1080: Loss = 0.00028318417
# epoch #1090: Loss = 2.5415432e-08
# epoch #1100: Loss = 2.5005358e-09
# epoch #1110: Loss = 5.715953
# epoch #1120: Loss = 0.77201355
# epoch #1130: Loss = 7.578449e-07
# epoch #1140: Loss = 3.0843796e-06
# epoch #1150: Loss = 4.1261895e-08
# epoch #1160: Loss = 1.2719701e-05
# epoch #1170: Loss = 9.913759e-09
# epoch #1180: Loss = 1.8379718e-07
# epoch #1190: Loss = 5.955915e-05
# epoch #1200: Loss = 0.010249498
# epoch #1210: Loss = 3.802066
# epoch #1220: Loss = 0.33609542
# epoch #1230: Loss = 6.6773487e-06
# epoch #1240: Loss = 4.893617e-07
# epoch #1250: Loss = 7.2954753e-09
# epoch #1260: Loss = 4.9683706e-08
# epoch #1270: Loss = 9.667374e-07
# epoch #1280: Loss = 1.141017e-06
# epoch #1290: Loss = 2.8674078
# epoch #1300: Loss = 2.9537467e-05
# epoch #1310: Loss = 0.057211764
# epoch #1320: Loss = 0.8129139
# epoch #1330: Loss = 1.0243395e-07
# epoch #1340: Loss = 2.5308375
# epoch #1350: Loss = 8.095878
# epoch #1360: Loss = 1.4284474e-08
# epoch #1370: Loss = 8.0296964e-08
# epoch #1380: Loss = 0.00019349792
# epoch #1390: Loss = 1.4522521e-06
# epoch #1400: Loss = 0.002217249
# epoch #1410: Loss = 0.0017652081
# epoch #1420: Loss = 2.8193707
# epoch #1430: Loss = 2.1397742e-05
# epoch #1440: Loss = 3.0021586
# epoch #1450: Loss = 2.3713372e-07
# epoch #1460: Loss = 0.0008390842
# epoch #1470: Loss = 0.0006700659
# epoch #1480: Loss = 3.3828792e-07
# epoch #1490: Loss = 8.084474e-06
# epoch #1500: Loss = 7.101671e-05
# epoch #1510: Loss = 2.6066587
# epoch #1520: Loss = 0.050323963
# epoch #1530: Loss = 0.0015142853
# epoch #1540: Loss = 0.08784482
# epoch #1550: Loss = 3.3946396e-06
# epoch #1560: Loss = 9.300458e-09
# epoch #1570: Loss = 4.8202393e-05
# epoch #1580: Loss = 6.261428
# epoch #1590: Loss = 1.9256142e-07
# epoch #1600: Loss = 3.1094537
# epoch #1610: Loss = 0.0065190946
# epoch #1620: Loss = 9.62255e-06
# epoch #1630: Loss = 4.2030243e-07
# epoch #1640: Loss = 2.7407007
# epoch #1650: Loss = 1.092339e-05
# epoch #1660: Loss = 6.533587e-05
# epoch #1670: Loss = 0.04742878
# epoch #1680: Loss = 0.0045123044
# epoch #1690: Loss = 2.460659e-05
# epoch #1700: Loss = 1.571556
# epoch #1710: Loss = 1.322614e-05
# epoch #1720: Loss = 0.0002002012
# epoch #1730: Loss = 1.2417801e-05
# epoch #1740: Loss = 7.777649e-07
# epoch #1750: Loss = 0.014919854
# epoch #1760: Loss = 2.0644703e-07
# epoch #1770: Loss = 3.309252e-06
# epoch #1780: Loss = 4.094153e-06
# epoch #1790: Loss = 0.00035058276
# epoch #1800: Loss = 0.047453918
# epoch #1810: Loss = 0.00014903875
# epoch #1820: Loss = 8.5725736e-07
# epoch #1830: Loss = 0.00045008646
# epoch #1840: Loss = 1.4620807e-05
# epoch #1850: Loss = 6.025115e-07
# epoch #1860: Loss = 4.4138308
# epoch #1870: Loss = 2.1595297e-06
# epoch #1880: Loss = 0.00021330995
# epoch #1890: Loss = 6.5152974
# epoch #1900: Loss = 0.15590711
# epoch #1910: Loss = 1.8955112e-05
# epoch #1920: Loss = 1.5894949e-07
# epoch #1930: Loss = 4.1235668e-07
# epoch #1940: Loss = 8.3298244e-07
# epoch #1950: Loss = 0.00035800965
# epoch #1960: Loss = 6.746322e-05
# epoch #1970: Loss = 0.00033756322
# epoch #1980: Loss = 3.023756e-06
# epoch #1990: Loss = 7.906723e-06
# epoch #2000: Loss = 4.9466493e-05
# epoch #2010: Loss = 0.00010103133
# epoch #2020: Loss = 6.1721894e-06
# epoch #2030: Loss = 4.3935353e-05
# epoch #2040: Loss = 6.554744
# epoch #2050: Loss = 9.307517e-07
# epoch #2060: Loss = 1.2322395
# epoch #2070: Loss = 0.0020513858
# epoch #2080: Loss = 0.42280024
# epoch #2090: Loss = 0.2006081
# epoch #2100: Loss = 0.41368544
# epoch #2110: Loss = 9.4253534e-07
# epoch #2120: Loss = 0.00031975174
# epoch #2130: Loss = 6.431033e-08
# epoch #2140: Loss = 0.0008267733
# epoch #2150: Loss = 3.1621974
# epoch #2160: Loss = 1.6068785
# epoch #2170: Loss = 2.4392111
# epoch #2180: Loss = 11.851887
# epoch #2190: Loss = 0.017897153
# epoch #2200: Loss = 1.396058e-05
# epoch #2210: Loss = 3.0285513
# epoch #2220: Loss = 3.2020303e-06
# epoch #2230: Loss = 0.00032478938
# epoch #2240: Loss = 6.464044e-06
# epoch #2250: Loss = 0.0002764614
# epoch #2260: Loss = 2.6729794
# epoch #2270: Loss = 8.827154e-05
# epoch #2280: Loss = 1.16213205e-05
# epoch #2290: Loss = 2.6804748
# epoch #2300: Loss = 0.6004275
# epoch #2310: Loss = 0.00094467466
# epoch #2320: Loss = 0.013319121
# epoch #2330: Loss = 0.0016985433
# epoch #2340: Loss = 3.9995157e-07
# epoch #2350: Loss = 13.131346
# epoch #2360: Loss = 1.5114013e-06
# epoch #2370: Loss = 5.4602805e-07
# epoch #2380: Loss = 2.6710482e-06
# epoch #2390: Loss = 6.9549926e-05
# epoch #2400: Loss = 1.2662747e-06
# epoch #2410: Loss = 0.01262809
# epoch #2420: Loss = 0.105449215
# epoch #2430: Loss = 0.003097078
# epoch #2440: Loss = 2.8817276e-06
# epoch #2450: Loss = 2.5604143
# epoch #2460: Loss = 2.4277602e-05
# epoch #2470: Loss = 0.0016987676
# epoch #2480: Loss = 2.277737e-05
# epoch #2490: Loss = 3.2055807e-06
# epoch #2500: Loss = 0.0005122663
# epoch #2510: Loss = 5.61058e-05
# epoch #2520: Loss = 5.17956e-07
# epoch #2530: Loss = 0.00031371528
# epoch #2540: Loss = 1.9105755e-06
# epoch #2550: Loss = 6.420388e-05
# epoch #2560: Loss = 0.00043654424
# epoch #2570: Loss = 2.5162812e-05
# epoch #2580: Loss = 3.1381915
# epoch #2590: Loss = 2.9459487e-05
# epoch #2600: Loss = 0.38534233
# epoch #2610: Loss = 11.822148
# epoch #2620: Loss = 0.20925769
# epoch #2630: Loss = 0.038466584
# epoch #2640: Loss = 3.629724
# epoch #2650: Loss = 6.8872194
# epoch #2660: Loss = 3.2366257e-05
# epoch #2670: Loss = 0.018786533
# epoch #2680: Loss = 0.14885616
# epoch #2690: Loss = 0.02442885
# epoch #2700: Loss = 0.00023433144
# epoch #2710: Loss = 3.1384712e-05
# epoch #2720: Loss = 5.9793887
# epoch #2730: Loss = 9.327656
# epoch #2740: Loss = 0.00015655336
# epoch #2750: Loss = 1.860447e-05
# epoch #2760: Loss = 0.0751401
# epoch #2770: Loss = 0.0005818178
# epoch #2780: Loss = 3.4327943e-06
# epoch #2790: Loss = 1.6478563e-05
# epoch #2800: Loss = 3.4376233
# epoch #2810: Loss = 0.00015938135
# epoch #2820: Loss = 0.10610658
# epoch #2830: Loss = 7.468824
# epoch #2840: Loss = 0.0002694019
# epoch #2850: Loss = 1.3671759
# epoch #2860: Loss = 1.581128e-05
# epoch #2870: Loss = 0.002205902
# epoch #2880: Loss = 0.00010358236
# epoch #2890: Loss = 1.3029304
# epoch #2900: Loss = 7.003838e-05
# epoch #2910: Loss = 0.00020491924
# epoch #2920: Loss = 0.0004921848
# epoch #2930: Loss = 4.987533e-05
# epoch #2940: Loss = 4.9900274
# epoch #2950: Loss = 2.0886097
# epoch #2960: Loss = 0.0013000884
# epoch #2970: Loss = 2.5718568e-06
# epoch #2980: Loss = 1.1859687e-05
# epoch #2990: Loss = 0.00065395236
# epoch #3000: Loss = 3.5882287
# epoch #3010: Loss = 0.5424431
# epoch #3020: Loss = 3.9410425e-05
# epoch #3030: Loss = 5.6444554e-07
# epoch #3040: Loss = 2.826631
# epoch #3050: Loss = 0.00014810439
# epoch #3060: Loss = 3.9657984e-06
# epoch #3070: Loss = 13.297188
# epoch #3080: Loss = 0.00071929395
# epoch #3090: Loss = 0.0031928546
# epoch #3100: Loss = 2.9333228e-06
# epoch #3110: Loss = 0.00020046905
# epoch #3120: Loss = 0.01867314
# epoch #3130: Loss = 0.00050651195
# epoch #3140: Loss = 5.535284e-05
# epoch #3150: Loss = 0.3463082
# epoch #3160: Loss = 0.0011295277
# epoch #3170: Loss = 0.0013990399
# epoch #3180: Loss = 3.7611144
# epoch #3190: Loss = 6.4462295
# epoch #3200: Loss = 0.10069479
# epoch #3210: Loss = 0.24177976
# epoch #3220: Loss = 2.0693738
# epoch #3230: Loss = 3.6570337
# epoch #3240: Loss = 3.530278
# epoch #3250: Loss = 0.0018457163
# epoch #3260: Loss = 0.4083314
# epoch #3270: Loss = 2.2776241e-05
# epoch #3280: Loss = 0.10924665
# epoch #3290: Loss = 0.01676027
# epoch #3300: Loss = 7.0654482e-06
# epoch #3310: Loss = 0.6104696
# epoch #3320: Loss = 0.0060009654
# epoch #3330: Loss = 0.14039238
# epoch #3340: Loss = 2.067245e-05
# epoch #3350: Loss = 1.4035388
# epoch #3360: Loss = 0.00037716186
# epoch #3370: Loss = 0.00019232921
# epoch #3380: Loss = 1.3857633e-05
# epoch #3390: Loss = 0.00046246406
# epoch #3400: Loss = 5.4921198e-05
# epoch #3410: Loss = 0.00016170264
# epoch #3420: Loss = 0.57681847
# epoch #3430: Loss = 0.00078832905
# epoch #3440: Loss = 0.1878953
# epoch #3450: Loss = 2.5848618
# epoch #3460: Loss = 0.10300931
# epoch #3470: Loss = 0.00065078697
# epoch #3480: Loss = 0.5417712
# epoch #3490: Loss = 0.048555568
# epoch #3500: Loss = 0.552492
# epoch #3510: Loss = 0.00015155907
# epoch #3520: Loss = 2.2826905
# epoch #3530: Loss = 9.003075e-05
# epoch #3540: Loss = 1.4933221
# epoch #3550: Loss = 0.00093016855
# epoch #3560: Loss = 1.1619774
# epoch #3570: Loss = 0.00045008434
# epoch #3580: Loss = 1.2033119e-05
# epoch #3590: Loss = 2.3191492e-06
# epoch #3600: Loss = 0.00034795908
# epoch #3610: Loss = 0.0005548236
# epoch #3620: Loss = 0.020915255
# epoch #3630: Loss = 0.013701597
# epoch #3640: Loss = 0.039196122
# epoch #3650: Loss = 2.297873
# epoch #3660: Loss = 10.344424
# epoch #3670: Loss = 0.009462452
# epoch #3680: Loss = 2.5003523e-05
# epoch #3690: Loss = 0.00063967897
# epoch #3700: Loss = 0.0025750662
# epoch #3710: Loss = 0.011045027
# epoch #3720: Loss = 0.75807476
# epoch #3730: Loss = 4.8348417
# epoch #3740: Loss = 0.039351378
# epoch #3750: Loss = 0.025004532
# epoch #3760: Loss = 0.039695706
# epoch #3770: Loss = 0.0008455577
# epoch #3780: Loss = 0.0045308676
# epoch #3790: Loss = 1.8883553
# epoch #3800: Loss = 1.2037662
# epoch #3810: Loss = 1.7040455e-05
# epoch #3820: Loss = 1.7439775e-06
# epoch #3830: Loss = 0.00017538149
# epoch #3840: Loss = 0.0015765179
# epoch #3850: Loss = 0.13757034
# epoch #3860: Loss = 0.00039159856
# epoch #3870: Loss = 0.00052729226
# epoch #3880: Loss = 0.052705016
# epoch #3890: Loss = 2.5919624e-05
# epoch #3900: Loss = 0.0005037384
# epoch #3910: Loss = 0.00085953105
# epoch #3920: Loss = 1.3667989e-06
# epoch #3930: Loss = 0.0003269576
# epoch #3940: Loss = 1.0335041e-05
# epoch #3950: Loss = 0.0003475327
# epoch #3960: Loss = 0.011016063
# epoch #3970: Loss = 6.860266
# epoch #3980: Loss = 3.5736917e-05
# epoch #3990: Loss = 0.0004133513
# epoch #4000: Loss = 1.0226887e-05
# epoch #4010: Loss = 1.5634007e-05
# epoch #4020: Loss = 1.0569344
# epoch #4030: Loss = 0.00034294653
# epoch #4040: Loss = 7.917467
# epoch #4050: Loss = 3.4544462e-06
# epoch #4060: Loss = 7.632575e-05
# epoch #4070: Loss = 0.0069883615
# epoch #4080: Loss = 5.2521264e-05
# epoch #4090: Loss = 2.6167536e-06
# epoch #4100: Loss = 0.013361558
# epoch #4110: Loss = 0.0010047205
# epoch #4120: Loss = 0.15490977
# epoch #4130: Loss = 0.0012191763
# epoch #4140: Loss = 2.5029797e-06
# epoch #4150: Loss = 0.010428126
# epoch #4160: Loss = 0.0020525598
# epoch #4170: Loss = 4.681875e-06
# epoch #4180: Loss = 1.1412828e-05
# epoch #4190: Loss = 0.004639802
# epoch #4200: Loss = 3.4384833e-05
# epoch #4210: Loss = 2.4459763
# epoch #4220: Loss = 2.4108765
# epoch #4230: Loss = 3.148535e-05
# epoch #4240: Loss = 0.0044614607
# epoch #4250: Loss = 2.9367347e-06
# epoch #4260: Loss = 0.00011588229
# epoch #4270: Loss = 4.660966e-07
# epoch #4280: Loss = 1.2135273e-06
# epoch #4290: Loss = 1.4167084
# epoch #4300: Loss = 1.1760103
# epoch #4310: Loss = 0.0213887
# epoch #4320: Loss = 2.9967208e-05
# epoch #4330: Loss = 0.013813808
# epoch #4340: Loss = 5.717172e-05
# epoch #4350: Loss = 0.0006712191
# epoch #4360: Loss = 0.00012479186
# epoch #4370: Loss = 3.8996847
# epoch #4380: Loss = 0.0007051027
# epoch #4390: Loss = 1.8622798
# epoch #4400: Loss = 0.0056222477
# epoch #4410: Loss = 3.7541013e-05
# epoch #4420: Loss = 2.600634
# epoch #4430: Loss = 6.358842
# epoch #4440: Loss = 0.25538844
# epoch #4450: Loss = 0.0017389415

# %%
print('使用测试集 {} 条数据预测.'.format(len(texts_test)))
test_acc_all = []
for ix, t in enumerate(vocab_processor.fit_transform(texts_test)):
    y_data = [[target_test[ix]]]
    
    if (ix+1)%50==0:
        print('epoch #' + str(ix+1))    
    

    [[temp_pred]] = sess.run(prediction, feed_dict={x_data:t, y_target:y_data})

    test_acc_temp = target_test[ix]==np.round(temp_pred)
    test_acc_all.append(test_acc_temp)

print('\n全部测试集的准确率为: {}'.format(np.mean(test_acc_all)))
# Out:
# 使用测试集 1115 条数据预测.
# epoch #50
# epoch #100
# epoch #150
# epoch #200
# epoch #250
# epoch #300
# epoch #350
# epoch #400
# epoch #450
# epoch #500
# epoch #550
# epoch #600
# epoch #650
# epoch #700
# epoch #750
# epoch #800
# epoch #850
# epoch #900
# epoch #950
# epoch #1000
# epoch #1050
# epoch #1100
#
# 全部测试集的准确率为: 0.8170403587443946

# %% [markdown]
# 可视化训练集的准确率曲线

# %%
plt.plot(range(len(train_acc_avg)), train_acc_avg, 'k-', label='Train Accuracy')
plt.title('Avg Training Acc Over Past 50 Iterations')
plt.xlabel('Iterations')
plt.ylabel('Training Accuracy')
plt.show()

# %%
plt.plot(loss_vec, 'k-', label='Train loss')

# %% [markdown]
# # 基于Tensorflow的TF-IDF
# 因为我们为每个单词选择词嵌入，使用可能需要调整某些特征单词的权重。在这种策略下，应提高有用词汇的权重，降低常用单词或者无意义单词的权重。<p>
#     这就是本节介绍的TF-IDF词嵌入方法<p>
# $w_{tf-idf} = w_{tf}*log(\frac{1}{w_{df}}) $

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import csv
import numpy as np
import os
import string
import requests
import io
import nltk
from zipfile import ZipFile
from sklearn.feature_extraction.text import TfidfVectorizer
from tensorflow.python.framework import ops
ops.reset_default_graph()
sess = tf.Session()

# %% [markdown]
# 1. batch_size是训练的批量大小
# 2. max_features为 TF-IDF 词汇表大小

# %%
batch_size = 512
max_features = 1000

# %% [markdown]
# 同上我们使用下载好的temp_spam_data.csv数据

# %%
save_file_name = os.path.join('temp','temp_spam_data.csv')
if os.path.isfile(save_file_name):
    text_data = []
    with open(save_file_name, 'r',newline='') as temp_output_file:
        reader = csv.reader(temp_output_file)
        for row in reader:
            text_data.append(row)
else:
    zip_url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/00228/smsspamcollection.zip'
    r = requests.get(zip_url)
    z = ZipFile(io.BytesIO(r.content))
    file = z.read('SMSSpamCollection')
    # Format Data
    text_data = file.decode()
    text_data = text_data.encode('ascii',errors='ignore')
    text_data = text_data.decode().split('\n')
    text_data = [x.split('\t') for x in text_data if len(x)>=1]
    
    # And write to csv
    with open(save_file_name, 'w',newline='') as temp_output_file:
        writer = csv.writer(temp_output_file)
        writer.writerow(text_data)

texts = [x[1] for x in text_data]
target = [x[0] for x in text_data]

# %% [markdown]
# 同上 进行一定数据预处理

# %%
target = [1. if x=='spam' else 0. for x in target]

# Normalize text
texts = [x.lower() for x in texts]
texts = [''.join(c for c in x if c not in string.punctuation) for x in texts]
texts = [''.join(c for c in x if c not in '0123456789') for x in texts]
texts = [' '.join(x.split()) for x in texts]

# %% [markdown]
# 1. 使用nltk的分词器，中文可以使用结巴
# 2. 使用scikit-learn的TF-IDF处理函数

# %%
def tokenizer(text):
    words = nltk.word_tokenize(text)
    return words

tfidf = TfidfVectorizer(tokenizer=tokenizer, stop_words='english', max_features=max_features)
sparse_tfidf_texts = tfidf.fit_transform(texts)

# %% [markdown]
# ### 中文TF-IDF化的一般步骤

# %%
'''
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer  
import jieba

all_text = [' '.join(jieba.cut(x)) for x in all_text]
train_texts = [' '.join(jieba.cut(x)) for x in train_texts]
test_texts = [' '.join(jieba.cut(x)) for x in test_texts]

V = CountVectorizer();    
counts_V = V .fit_transform(all_text); 

train_V = CountVectorizer(vocabulary=V.vocabulary_) 
counts_train = train_V.fit_transform(train_texts)

test_V = CountVectorizer(vocabulary=V.vocabulary_)  
counts_test = test_V.fit_transform(test_texts)

tfidftransformer = TfidfTransformer();      
train_data = tfidftransformer.fit(counts_train).transform(counts_train)
test_data = tfidftransformer.fit(counts_test).transform(counts_test)
'''
# Out:
# "\nfrom sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer  \nimport jieba\n\nall_text = [' '.join(jieba.cut(x)) for x in all_text]\ntrain_texts = [' '.join(jieba.cut(x)) for x in train_texts]\ntest_texts = [' '.join(jieba.cut(x)) for x in test_texts]\n\nV = CountVectorizer();    \ncounts_V = V .fit_transform(all_text); \n\ntrain_V = CountVectorizer(vocabulary=V.vocabulary_) \ncounts_train = train_V.fit_transform(train_texts)\n\ntest_V = CountVectorizer(vocabulary=V.vocabulary_)  \ncounts_test = test_V.fit_transform(test_texts)\n\ntfidftransformer = TfidfTransformer();      \ntrain_data = tfidftransformer.fit(counts_train).transform(counts_train)\ntest_data = tfidftransformer.fit(counts_test).transform(counts_test)\n"

# %% [markdown]
# 分割数据集

# %%
train_indices = np.random.choice(sparse_tfidf_texts.shape[0], round(0.8*sparse_tfidf_texts.shape[0]), replace=False)
test_indices = np.array(list(set(range(sparse_tfidf_texts.shape[0])) - set(train_indices)))
texts_train = sparse_tfidf_texts[train_indices]
texts_test = sparse_tfidf_texts[test_indices]
target_train = np.array([x for ix, x in enumerate(target) if ix in train_indices])
target_test = np.array([x for ix, x in enumerate(target) if ix in test_indices])

# %%
# 创建初始化矩阵
w = tf.Variable(tf.random_normal(shape=[max_features,1]))
b = tf.Variable(tf.random_normal(shape=[1,1]))

# 占位符
x_data = tf.placeholder(shape=[None, max_features], dtype=tf.float32)
y_target = tf.placeholder(shape=[None, 1], dtype=tf.float32)

model_output = tf.add(tf.matmul(x_data, w), b)

# 交叉熵损失函数
loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=model_output, labels=y_target))

# 预测
prediction = tf.round(tf.sigmoid(model_output))
predictions_correct = tf.cast(tf.equal(prediction, y_target), tf.float32)
accuracy = tf.reduce_mean(predictions_correct)

# 优化器
my_opt = tf.train.GradientDescentOptimizer(0.0025)
train_step = my_opt.minimize(loss)

# 初始化
init = tf.global_variables_initializer()
sess.run(init)

# %%
train_loss = []
test_loss = []
train_acc = []
test_acc = []
i_data = []
for i in range(10000):
    rand_index = np.random.choice(texts_train.shape[0], size=batch_size)
    rand_x = texts_train[rand_index].todense()
    rand_y = np.transpose([target_train[rand_index]])
    sess.run(train_step, feed_dict={x_data: rand_x, y_target: rand_y})

    if (i+1)%100==0:
        i_data.append(i+1)
        train_loss_temp = sess.run(loss, feed_dict={x_data: rand_x, y_target: rand_y})
        train_loss.append(train_loss_temp)
        
        test_loss_temp = sess.run(loss, feed_dict={x_data: texts_test.todense(), y_target: np.transpose([target_test])})
        test_loss.append(test_loss_temp)
        
        train_acc_temp = sess.run(accuracy, feed_dict={x_data: rand_x, y_target: rand_y})
        train_acc.append(train_acc_temp)
    
        test_acc_temp = sess.run(accuracy, feed_dict={x_data: texts_test.todense(), y_target: np.transpose([target_test])})
        test_acc.append(test_acc_temp)
    if (i+1)%500==0:
        acc_and_loss = [i+1, train_loss_temp, test_loss_temp, train_acc_temp, test_acc_temp]
        acc_and_loss = [np.round(x,2) for x in acc_and_loss]
        print('epoch # {}. Train Loss (Test Loss): {:.2f} ({:.2f}). Train Acc (Test Acc): {:.2f} ({:.2f})'.format(*acc_and_loss))
# Out:
# epoch # 500. Train Loss (Test Loss): 0.77 (0.75). Train Acc (Test Acc): 0.49 (0.53)
# epoch # 1000. Train Loss (Test Loss): 0.67 (0.63). Train Acc (Test Acc): 0.62 (0.66)
# epoch # 1500. Train Loss (Test Loss): 0.58 (0.56). Train Acc (Test Acc): 0.68 (0.72)
# epoch # 2000. Train Loss (Test Loss): 0.55 (0.51). Train Acc (Test Acc): 0.74 (0.78)
# epoch # 2500. Train Loss (Test Loss): 0.52 (0.48). Train Acc (Test Acc): 0.76 (0.80)
# epoch # 3000. Train Loss (Test Loss): 0.46 (0.46). Train Acc (Test Acc): 0.81 (0.81)
# epoch # 3500. Train Loss (Test Loss): 0.49 (0.45). Train Acc (Test Acc): 0.80 (0.83)
# epoch # 4000. Train Loss (Test Loss): 0.43 (0.44). Train Acc (Test Acc): 0.83 (0.84)
# epoch # 4500. Train Loss (Test Loss): 0.45 (0.43). Train Acc (Test Acc): 0.82 (0.84)
# epoch # 5000. Train Loss (Test Loss): 0.48 (0.43). Train Acc (Test Acc): 0.80 (0.85)
# epoch # 5500. Train Loss (Test Loss): 0.42 (0.42). Train Acc (Test Acc): 0.86 (0.86)
# epoch # 6000. Train Loss (Test Loss): 0.44 (0.42). Train Acc (Test Acc): 0.85 (0.86)
# epoch # 6500. Train Loss (Test Loss): 0.47 (0.42). Train Acc (Test Acc): 0.84 (0.86)
# epoch # 7000. Train Loss (Test Loss): 0.45 (0.42). Train Acc (Test Acc): 0.83 (0.86)
# epoch # 7500. Train Loss (Test Loss): 0.44 (0.42). Train Acc (Test Acc): 0.86 (0.86)
# epoch # 8000. Train Loss (Test Loss): 0.46 (0.41). Train Acc (Test Acc): 0.83 (0.87)
# epoch # 8500. Train Loss (Test Loss): 0.48 (0.41). Train Acc (Test Acc): 0.84 (0.87)
# epoch # 9000. Train Loss (Test Loss): 0.42 (0.41). Train Acc (Test Acc): 0.87 (0.87)
# epoch # 9500. Train Loss (Test Loss): 0.48 (0.41). Train Acc (Test Acc): 0.84 (0.87)
# epoch # 10000. Train Loss (Test Loss): 0.45 (0.41). Train Acc (Test Acc): 0.85 (0.87)

# %% [markdown]
# ## 可视化Loss曲线和acc曲线

# %%
plt.plot(i_data, train_loss, 'k-', label='Train Loss')
plt.plot(i_data, test_loss, 'r--', label='Test Loss', linewidth=4)
plt.title('Cross Entropy Loss per Generation')
plt.xlabel('Generation')
plt.ylabel('Cross Entropy Loss')
plt.legend(loc='upper right')
plt.show()
plt.plot(i_data, train_acc, 'k-', label='Train Set Accuracy')
plt.plot(i_data, test_acc, 'r--', label='Test Set Accuracy', linewidth=4)
plt.title('Train and Test Accuracy')
plt.xlabel('Generation')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# %% [markdown]
# ### 改写成用神经网络来训练上面模型

# %% [markdown]
# * config参数

# %%
batch_size = 512
max_features = 1200
epoch = 10000
layer2_dim = 10

# %% [markdown]
# 之前步骤同上,不做改变

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import csv
import numpy as np
import os
import string
import requests
import io
import nltk
from zipfile import ZipFile
from sklearn.feature_extraction.text import TfidfVectorizer
from tensorflow.python.framework import ops
ops.reset_default_graph()
sess = tf.Session()



save_file_name = os.path.join('temp','temp_spam_data.csv')
if os.path.isfile(save_file_name):
    text_data = []
    with open(save_file_name, 'r',newline='') as temp_output_file:
        reader = csv.reader(temp_output_file)
        for row in reader:
            text_data.append(row)
else:
    zip_url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/00228/smsspamcollection.zip'
    r = requests.get(zip_url)
    z = ZipFile(io.BytesIO(r.content))
    file = z.read('SMSSpamCollection')
    # Format Data
    text_data = file.decode()
    text_data = text_data.encode('ascii',errors='ignore')
    text_data = text_data.decode().split('\n')
    text_data = [x.split('\t') for x in text_data if len(x)>=1]
    
    # And write to csv
    with open(save_file_name, 'w',newline='') as temp_output_file:
        writer = csv.writer(temp_output_file)
        writer.writerow(text_data)

texts = [x[1] for x in text_data]
target = [x[0] for x in text_data]

target = [1. if x=='spam' else 0. for x in target]

# Normalize text
texts = [x.lower() for x in texts]
texts = [''.join(c for c in x if c not in string.punctuation) for x in texts]
texts = [''.join(c for c in x if c not in '0123456789') for x in texts]
texts = [' '.join(x.split()) for x in texts]

def tokenizer(text):
    words = nltk.word_tokenize(text)
    return words

tfidf = TfidfVectorizer(tokenizer=tokenizer, stop_words='english', max_features=max_features)
sparse_tfidf_texts = tfidf.fit_transform(texts)

train_indices = np.random.choice(sparse_tfidf_texts.shape[0], round(0.8*sparse_tfidf_texts.shape[0]), replace=False)
test_indices = np.array(list(set(range(sparse_tfidf_texts.shape[0])) - set(train_indices)))
texts_train = sparse_tfidf_texts[train_indices]
texts_test = sparse_tfidf_texts[test_indices]
target_train = np.array([x for ix, x in enumerate(target) if ix in train_indices])
target_test = np.array([x for ix, x in enumerate(target) if ix in test_indices])

# %%
# Layer 1
w = tf.Variable(tf.random_normal(shape=[max_features,layer2_dim]))
b = tf.Variable(tf.random_normal(shape=[layer2_dim]))


# Layer 2
w2 = tf.Variable(tf.random_normal(shape=[layer2_dim,1]))
b2 = tf.Variable(tf.random_normal(shape=[1]))



# 占位符
x_data = tf.placeholder(shape=[None, max_features], dtype=tf.float32)
y_target = tf.placeholder(shape=[None, 1], dtype=tf.float32)


hiddle = tf.sigmoid(tf.add(tf.matmul(x_data,w),b))
model_output = tf.add(tf.matmul(hiddle,w2),b2)

# 交叉熵损失函数
loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=model_output, labels=y_target))

# 预测
prediction = tf.round(tf.sigmoid(model_output))
predictions_correct = tf.cast(tf.equal(prediction, y_target), tf.float32)
accuracy = tf.reduce_mean(predictions_correct)

# 优化器
my_opt = tf.train.GradientDescentOptimizer(0.0025)
train_step = my_opt.minimize(loss)

# 初始化
init = tf.global_variables_initializer()
sess.run(init)

# %%
train_loss = []
test_loss = []
train_acc = []
test_acc = []
i_data = []
for i in range(10000):
    rand_index = np.random.choice(texts_train.shape[0], size=batch_size)
    rand_x = texts_train[rand_index].todense()
    rand_y = np.transpose([target_train[rand_index]])
    sess.run(train_step, feed_dict={x_data: rand_x, y_target: rand_y})

    if (i+1)%100==0:
        i_data.append(i+1)
        train_loss_temp = sess.run(loss, feed_dict={x_data: rand_x, y_target: rand_y})
        train_loss.append(train_loss_temp)
        
        test_loss_temp = sess.run(loss, feed_dict={x_data: texts_test.todense(), y_target: np.transpose([target_test])})
        test_loss.append(test_loss_temp)
        
        train_acc_temp = sess.run(accuracy, feed_dict={x_data: rand_x, y_target: rand_y})
        train_acc.append(train_acc_temp)
    
        test_acc_temp = sess.run(accuracy, feed_dict={x_data: texts_test.todense(), y_target: np.transpose([target_test])})
        test_acc.append(test_acc_temp)
    if (i+1)%500==0:
        acc_and_loss = [i+1, train_loss_temp, test_loss_temp, train_acc_temp, test_acc_temp]
        acc_and_loss = [np.round(x,2) for x in acc_and_loss]
        print('epoch # {}. Train Loss (Test Loss): {:.2f} ({:.2f}). Train Acc (Test Acc): {:.2f} ({:.2f})'.format(*acc_and_loss))
# Out:
# epoch # 500. Train Loss (Test Loss): 0.52 (0.49). Train Acc (Test Acc): 0.84 (0.84)
# epoch # 1000. Train Loss (Test Loss): 0.40 (0.41). Train Acc (Test Acc): 0.88 (0.87)
# epoch # 1500. Train Loss (Test Loss): 0.33 (0.40). Train Acc (Test Acc): 0.90 (0.87)
# epoch # 2000. Train Loss (Test Loss): 0.44 (0.40). Train Acc (Test Acc): 0.84 (0.87)
# epoch # 2500. Train Loss (Test Loss): 0.38 (0.39). Train Acc (Test Acc): 0.87 (0.87)
# epoch # 3000. Train Loss (Test Loss): 0.42 (0.39). Train Acc (Test Acc): 0.86 (0.87)
# epoch # 3500. Train Loss (Test Loss): 0.39 (0.39). Train Acc (Test Acc): 0.87 (0.87)
# epoch # 4000. Train Loss (Test Loss): 0.38 (0.39). Train Acc (Test Acc): 0.88 (0.87)
# epoch # 4500. Train Loss (Test Loss): 0.38 (0.39). Train Acc (Test Acc): 0.88 (0.87)
# epoch # 5000. Train Loss (Test Loss): 0.42 (0.39). Train Acc (Test Acc): 0.86 (0.87)
# epoch # 5500. Train Loss (Test Loss): 0.40 (0.39). Train Acc (Test Acc): 0.86 (0.87)
# epoch # 6000. Train Loss (Test Loss): 0.42 (0.39). Train Acc (Test Acc): 0.85 (0.87)
# epoch # 6500. Train Loss (Test Loss): 0.42 (0.39). Train Acc (Test Acc): 0.86 (0.87)
# epoch # 7000. Train Loss (Test Loss): 0.41 (0.39). Train Acc (Test Acc): 0.87 (0.87)
# epoch # 7500. Train Loss (Test Loss): 0.38 (0.39). Train Acc (Test Acc): 0.88 (0.87)
# epoch # 8000. Train Loss (Test Loss): 0.46 (0.39). Train Acc (Test Acc): 0.83 (0.87)
# epoch # 8500. Train Loss (Test Loss): 0.35 (0.39). Train Acc (Test Acc): 0.89 (0.87)
# epoch # 9000. Train Loss (Test Loss): 0.39 (0.39). Train Acc (Test Acc): 0.88 (0.87)
# epoch # 9500. Train Loss (Test Loss): 0.42 (0.39). Train Acc (Test Acc): 0.86 (0.87)
# epoch # 10000. Train Loss (Test Loss): 0.42 (0.39). Train Acc (Test Acc): 0.85 (0.87)

# %%
plt.plot(i_data, train_loss, 'k-', label='Train Loss')
plt.plot(i_data, test_loss, 'r--', label='Test Loss', linewidth=4)
plt.title('Cross Entropy Loss per Generation')
plt.xlabel('Generation')
plt.ylabel('Cross Entropy Loss')
plt.legend(loc='upper right')
plt.show()
plt.plot(i_data, train_acc, 'k-', label='Train Set Accuracy')
plt.plot(i_data, test_acc, 'r--', label='Test Set Accuracy', linewidth=4)
plt.title('Train and Test Accuracy')
plt.xlabel('Generation')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# %% [markdown]
# # Word2Vec: Skipgram Model
#
# [了解Word2Vec的参数解释请点击此](https://blog.csdn.net/qq_41664845/article/details/82971728)
#
# 在此示例中，我们将下载并预处理电影评论数据。
#
# 从这个数据集中，我们将计算/拟合Word2Vec算法的skipgram模型
#
# Skipgram：基于给出词预测周围的单词
#
# 示例：“the cat in the hat”
#   - context word：“hat”
#   - target words：“the”，“cat”，“in”，“the”
#   - context-target pairs:(“hat”，“the”），（“hat”，“cat”），（“hat”，“in”），（“hat”，“the”）

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import random
import os
import string
import requests
import collections
import io
import tarfile
import gzip
from nltk.corpus import stopwords
from tensorflow.python.framework import ops
ops.reset_default_graph()
sess = tf.Session()

# %% [markdown]
# ### config parameters：
# 1. batch_size----------------批量训练的大小
# 2. embedding_size--------每个词向量的维度
# 3. vocabulary_size--------词汇表大小决定了有多少单词可以被训练
# 4. generations--------------单词频次阈值
# 5. num_sampled----------负抽样的数量
# 6. window_size------------考虑附件几个单词

# %%
batch_size = 100        
embedding_size = 100   
vocabulary_size = 5000 
generations = 100000   
print_loss_every = 500  

num_sampled = int(batch_size/2) 
window_size = 2         

#  stop words
stops = stopwords.words('english')

print_valid_every = 10000
valid_words = ['cliche', 'love', 'hate', 'silly', 'sad']

# %% [markdown]
# * 下载数据，方便调用调试.逻辑与之前相似

# %%
def load_movie_data():
    save_folder_name = 'temp'
    pos_file = os.path.join(save_folder_name, 'rt-polaritydata', 'rt-polarity.pos')
    neg_file = os.path.join(save_folder_name, 'rt-polaritydata', 'rt-polarity.neg')

    # Check if files are already downloaded
    if not os.path.exists(os.path.join(save_folder_name, 'rt-polaritydata')):
        movie_data_url = 'http://www.cs.cornell.edu/people/pabo/movie-review-data/rt-polaritydata.tar.gz'

        # Save tar.gz file
        req = requests.get(movie_data_url, stream=True)
        with open(os.path.join(save_folder_name,'temp_movie_review_temp.tar.gz'), 'wb') as f:
            for chunk in req.iter_content(chunk_size=1024):
                if chunk:
                    f.write(chunk)
                    f.flush()
        # Extract tar.gz file into temp folder
        tar = tarfile.open(os.path.join(save_folder_name,'temp_movie_review_temp.tar.gz'), "r:gz")
        tar.extractall(path='temp')
        tar.close()

    pos_data = []
    with open(pos_file, 'r', encoding='latin-1') as f:
        for line in f:
            pos_data.append(line.encode('ascii',errors='ignore').decode())
    f.close()
    pos_data = [x.rstrip() for x in pos_data]

    neg_data = []
    with open(neg_file, 'r', encoding='latin-1') as f:
        for line in f:
            neg_data.append(line.encode('ascii',errors='ignore').decode())
    f.close()
    neg_data = [x.rstrip() for x in neg_data]
    
    texts = pos_data + neg_data
    target = [1]*len(pos_data) + [0]*len(neg_data)
    
    return(texts, target)


texts, target = load_movie_data()

# %% [markdown]
# 加上一定的数据预处理，和之前一样，变全小写，去除标点符号，去除数字

# %%
def normalize_text(texts, stops):
    # Lower case
    texts = [x.lower() for x in texts]

    # Remove punctuation
    texts = [''.join(c for c in x if c not in string.punctuation) for x in texts]

    # Remove numbers
    texts = [''.join(c for c in x if c not in '0123456789') for x in texts]

    # Remove stopwords
    texts = [' '.join([word for word in x.split() if word not in (stops)]) for x in texts]

    # Trim extra whitespace
    texts = [' '.join(x.split()) for x in texts]
    
    return(texts)
    
texts = normalize_text(texts, stops)

# 舍去少于3个单词的评论数据
target = [target[ix] for ix, x in enumerate(texts) if len(x.split()) > 2]
texts = [x for x in texts if len(x.split()) > 2]

# %% [markdown]
# #### 构建词汇表

# %%
def build_dictionary(sentences, vocabulary_size):
    # 将分词后的序列转化为全部单词的列表
    split_sentences = [s.split() for s in sentences]
    words = [x for sublist in split_sentences for x in sublist]
    
    # 初始化一个列表 记录每个单词的word，count
    count = [('RARE', -1)]
    
    # 按词频统计的排序结果插入到count中
    count.extend(collections.Counter(words).most_common(vocabulary_size-1))
  
    word_dict = {}
    
    # 为词汇表的每个单词构建索引
    for word, word_count in count:
        word_dict[word] = len(word_dict)
   
    return(word_dict)

def text_to_numbers(sentences, word_dict):

    data = []
    for sentence in sentences:
        sentence_data = []
        
        for word in sentence.split(' '):
            if word in word_dict:
                word_ix = word_dict[word]
            else:
                word_ix = 0
            sentence_data.append(word_ix)
        data.append(sentence_data)
    return(data)

# 构建词汇表，并将电影评论数据按词汇表索引转化成数字列表
word_dictionary = build_dictionary(texts, vocabulary_size)
word_dictionary_rev = dict(zip(word_dictionary.values(), word_dictionary.keys()))
text_data = text_to_numbers(texts, word_dictionary)

# 获取验证数据的索引
valid_examples = [word_dictionary[x] for x in valid_words]

# %%
def generate_batch_data(sentences, batch_size, window_size, method='skip_gram'):
    batch_data = []
    label_data = []
    while len(batch_data) < batch_size:
        # 随机选取一条数据
        rand_sentence = np.random.choice(sentences)
        # 构建windows 填入数据
        window_sequences = [rand_sentence[max((ix-window_size),0):(ix+window_size+1)] for ix, x in enumerate(rand_sentence)]
        # 索引
        label_indices = [ix if ix<window_size else window_size for ix,x in enumerate(window_sequences)]
        
        # Pull out center word of interest for each window and create a tuple for each window
        if method=='skip_gram':
            batch_and_labels = [(x[y], x[:y] + x[(y+1):]) for x,y in zip(window_sequences, label_indices)]
            # Make it in to a big list of tuples (target word, surrounding word)
            tuple_data = [(x, y_) for x,y in batch_and_labels for y_ in y]
        elif method=='cbow':
            batch_and_labels = [(x[:y] + x[(y+1):], x[y]) for x,y in zip(window_sequences, label_indices)]
            # Make it in to a big list of tuples (target word, surrounding word)
            tuple_data = [(x_, y) for x,y in batch_and_labels for x_ in x]
        else:
            raise ValueError('Method {} not implemented yet.'.format(method))
            
        # extract batch and labels
        batch, labels = [list(x) for x in zip(*tuple_data)]
        batch_data.extend(batch[:batch_size])
        label_data.extend(labels[:batch_size])
    # Trim batch and label at the end
    batch_data = batch_data[:batch_size]
    label_data = label_data[:batch_size]
    
    # Convert to numpy array
    batch_data = np.array(batch_data)
    label_data = np.transpose(np.array([label_data]))
    
    return(batch_data, label_data)

# %%
embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))

nce_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                                               stddev=1.0 / np.sqrt(embedding_size)))
nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

x_inputs = tf.placeholder(tf.int32, shape=[batch_size])
y_target = tf.placeholder(tf.int32, shape=[batch_size, 1])
valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

# Lookup the word embedding:
embed = tf.nn.embedding_lookup(embeddings, x_inputs)

# %%
# loss
loss = tf.reduce_mean(tf.nn.nce_loss(weights=nce_weights,
                                     biases=nce_biases,
                                     labels=y_target,
                                     inputs=embed,
                                     num_sampled=num_sampled,
                                     num_classes=vocabulary_size))

# 优化器
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1.0).minimize(loss)

# 余弦相似度距离
norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
normalized_embeddings = embeddings / norm
valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
similarity = tf.matmul(valid_embeddings, normalized_embeddings, transpose_b=True)

#初始化
init = tf.global_variables_initializer()
sess.run(init)
# Out:
# WARNING:tensorflow:From <ipython-input-42-30a3611a12de>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
sim_init = sess.run(similarity)

# %%
# Run the skip gram model.
loss_vec = []
loss_x_vec = []
for i in range(generations):
    batch_inputs, batch_labels = generate_batch_data(text_data, batch_size, window_size)
    feed_dict = {x_inputs : batch_inputs, y_target : batch_labels}

    # Run the train step
    sess.run(optimizer, feed_dict=feed_dict)

    # Return the loss
    if (i+1) % print_loss_every == 0:
        loss_val = sess.run(loss, feed_dict=feed_dict)
        loss_vec.append(loss_val)
        loss_x_vec.append(i+1)
        print("Loss at step {} : {}".format(i+1, loss_val))
      
    # Validation: Print some random words and top 5 related words
    if (i+1) % print_valid_every == 0:
        sim = sess.run(similarity)
        for j in range(len(valid_words)):
            valid_word = word_dictionary_rev[valid_examples[j]]
            top_k = 5 # number of nearest neighbors
            nearest = (-sim[j, :]).argsort()[1:top_k+1]
            log_str = "Nearest to {}:".format(valid_word)
            for k in range(top_k):
                close_word = word_dictionary_rev[nearest[k]]
                score = sim[j,nearest[k]]
                log_str = "%s %s," % (log_str, close_word)
            print(log_str)
# Out:
# Loss at step 500 : 34.535850524902344
# Loss at step 1000 : 5.2022600173950195
# Loss at step 1500 : 5.691699981689453
# Loss at step 2000 : 10.468977928161621
# Loss at step 2500 : 5.3306708335876465
# Loss at step 3000 : 4.104818344116211
# Loss at step 3500 : 3.263632297515869
# Loss at step 4000 : 4.134164810180664
# Loss at step 4500 : 4.037637710571289
# Loss at step 5000 : 4.329546928405762
# Loss at step 5500 : 3.838724374771118
# Loss at step 6000 : 4.095505237579346
# Loss at step 6500 : 4.266180038452148
# Loss at step 7000 : 3.9041717052459717
# Loss at step 7500 : 3.870939254760742
# Loss at step 8000 : 4.233078956604004
# Loss at step 8500 : 4.14624547958374
# Loss at step 9000 : 4.028567790985107
# Loss at step 9500 : 3.92509126663208
# Loss at step 10000 : 3.899758815765381
# Nearest to cliche: tosca, urban, distasteful, RARE, oscar,
# Nearest to love: hes, caine, lingers, band, igby,
# Nearest to hate: clue, depressing, pale, smooth, correct,
# Nearest to silly: consistent, brings, lousy, absolute, floor,
# Nearest to sad: escaped, fighting, los, creative, playing,
# Loss at step 10500 : 4.005655288696289
# Loss at step 11000 : 4.2893266677856445
# Loss at step 11500 : 3.8491148948669434
# Loss at step 12000 : 3.82578182220459
# Loss at step 12500 : 3.644662857055664
# Loss at step 13000 : 3.8617682456970215
# Loss at step 13500 : 3.8228440284729004
# Loss at step 14000 : 4.222132682800293
# Loss at step 14500 : 4.047975540161133
# Loss at step 15000 : 3.886324167251587
# Loss at step 15500 : 3.605926513671875
# Loss at step 16000 : 4.301939010620117
# Loss at step 16500 : 3.8537845611572266
# Loss at step 17000 : 4.098751544952393
# Loss at step 17500 : 3.879437208175659
# Loss at step 18000 : 4.114456653594971
# Loss at step 18500 : 3.8753232955932617
# Loss at step 19000 : 3.990776300430298
# Loss at step 19500 : 4.018248081207275
# Loss at step 20000 : 4.2771830558776855
# Nearest to cliche: tosca, urban, distasteful, oscar, breathes,
# Nearest to love: lingers, complications, experienced, caine, clashing,
# Nearest to hate: clue, pale, depressing, correct, smooth,
# Nearest to silly: consistent, absolute, floor, brings, lousy,
# Nearest to sad: fighting, escaped, creative, madonna, playing,
# Loss at step 20500 : 3.9760124683380127
# Loss at step 21000 : 3.6384081840515137
# Loss at step 21500 : 3.866926908493042
# Loss at step 22000 : 3.8747165203094482
# Loss at step 22500 : 3.9268176555633545
# Loss at step 23000 : 3.552009344100952
# Loss at step 23500 : 3.943099021911621
# Loss at step 24000 : 3.5554070472717285
# Loss at step 24500 : 3.427396774291992
# Loss at step 25000 : 3.740769386291504
# Loss at step 25500 : 3.6314990520477295
# Loss at step 26000 : 3.6279547214508057
# Loss at step 26500 : 3.5369861125946045
# Loss at step 27000 : 3.7950615882873535
# Loss at step 27500 : 4.127297878265381
# Loss at step 28000 : 3.5005674362182617
# Loss at step 28500 : 4.065853595733643
# Loss at step 29000 : 3.533329486846924
# Loss at step 29500 : 3.8732030391693115
# Loss at step 30000 : 3.6242966651916504
# Nearest to cliche: tosca, urban, distasteful, oscar, rather,
# Nearest to love: experienced, complications, clashing, lingers, attitude,
# Nearest to hate: clue, pale, depressing, correct, foibles,
# Nearest to silly: consistent, floor, absolute, plodding, figures,
# Nearest to sad: animation, count, madonna, escaped, sweetness,
# Loss at step 30500 : 3.6710400581359863
# Loss at step 31000 : 3.5891785621643066
# Loss at step 31500 : 4.267165660858154
# Loss at step 32000 : 3.7285802364349365
# Loss at step 32500 : 3.1061949729919434
# Loss at step 33000 : 3.728022575378418
# Loss at step 33500 : 3.488210439682007
# Loss at step 34000 : 3.5966150760650635
# Loss at step 34500 : 4.057029724121094
# Loss at step 35000 : 3.762394428253174
# Loss at step 35500 : 3.7864458560943604
# Loss at step 36000 : 3.458343267440796
# Loss at step 36500 : 3.759669780731201
# Loss at step 37000 : 3.684560537338257
# Loss at step 37500 : 3.6856191158294678
# Loss at step 38000 : 3.4010965824127197
# Loss at step 38500 : 3.982170820236206
# Loss at step 39000 : 3.781776189804077
# Loss at step 39500 : 3.7060012817382812
# Loss at step 40000 : 3.879281997680664
# Nearest to cliche: tosca, urban, distasteful, oscar, rather,
# Nearest to love: complications, clashing, experienced, lingers, caine,
# Nearest to hate: clue, pale, foibles, depressing, correct,
# Nearest to silly: consistent, floor, plodding, absolute, ultimately,
# Nearest to sad: madonna, escaped, sweetness, count, animation,
# Loss at step 40500 : 3.7762229442596436
# Loss at step 41000 : 3.558835983276367
# Loss at step 41500 : 3.5472512245178223
# Loss at step 42000 : 3.647174596786499
# Loss at step 42500 : 3.8407833576202393
# Loss at step 43000 : 3.5766212940216064
# Loss at step 43500 : 4.304776191711426
# Loss at step 44000 : 3.2876574993133545
# Loss at step 44500 : 3.762146234512329
# Loss at step 45000 : 3.9651010036468506
# Loss at step 45500 : 3.6492526531219482
# Loss at step 46000 : 3.8428614139556885
# Loss at step 46500 : 3.5703635215759277
# Loss at step 47000 : 3.415464401245117
# Loss at step 47500 : 3.1498632431030273
# Loss at step 48000 : 3.4889626502990723
# Loss at step 48500 : 3.997077226638794
# Loss at step 49000 : 3.4508652687072754
# Loss at step 49500 : 3.6049370765686035
# Loss at step 50000 : 3.9856600761413574
# Nearest to cliche: tosca, distasteful, urban, fighting, rather,
# Nearest to love: complications, RARE, clashing, experienced, likable,
# Nearest to hate: clue, pale, foibles, correct, depressing,
# Nearest to silly: consistent, plodding, floor, absolute, moved,
# Nearest to sad: madonna, count, sweetness, animation, gift,
# Loss at step 50500 : 3.5379836559295654
# Loss at step 51000 : 3.569744825363159
# Loss at step 51500 : 3.527034282684326
# Loss at step 52000 : 3.2835259437561035
# Loss at step 52500 : 3.501495361328125
# Loss at step 53000 : 3.704646587371826
# Loss at step 53500 : 3.431978702545166
# Loss at step 54000 : 3.3426053524017334
# Loss at step 54500 : 3.6445658206939697
# Loss at step 55000 : 3.8678841590881348
# Loss at step 55500 : 3.590221643447876
# Loss at step 56000 : 3.1589515209198
# Loss at step 56500 : 3.2924747467041016
# Loss at step 57000 : 3.2991907596588135
# Loss at step 57500 : 3.19589900970459
# Loss at step 58000 : 3.961604356765747
# Loss at step 58500 : 3.3628387451171875
# Loss at step 59000 : 3.2200958728790283
# Loss at step 59500 : 3.5307319164276123
# Loss at step 60000 : 3.51225209236145
# Nearest to cliche: tosca, distasteful, urban, fighting, upbeat,
# Nearest to love: complications, clashing, igby, experienced, likable,
# Nearest to hate: clue, pale, correct, foibles, fool,
# Nearest to silly: consistent, plodding, floor, absolute, enormously,
# Nearest to sad: count, madonna, gift, animation, sweetness,
# Loss at step 60500 : 3.404949903488159
# Loss at step 61000 : 2.956408739089966
# Loss at step 61500 : 3.8540868759155273
# Loss at step 62000 : 3.8232979774475098
# Loss at step 62500 : 3.1735684871673584
# Loss at step 63000 : 3.6104507446289062
# Loss at step 63500 : 3.1898629665374756
# Loss at step 64000 : 3.9474432468414307
# Loss at step 64500 : 3.628483295440674
# Loss at step 65000 : 3.4164319038391113
# Loss at step 65500 : 3.0598642826080322
# Loss at step 66000 : 3.3353402614593506
# Loss at step 66500 : 3.309654474258423
# Loss at step 67000 : 3.2473621368408203
# Loss at step 67500 : 3.5330002307891846
# Loss at step 68000 : 3.518068790435791
# Loss at step 68500 : 4.008988380432129
# Loss at step 69000 : 3.0106191635131836
# Loss at step 69500 : 3.5880508422851562
# Loss at step 70000 : 3.683772087097168
# Nearest to cliche: tosca, distasteful, urban, RARE, fighting,
# Nearest to love: complications, clashing, igby, likable, severe,
# Nearest to hate: clue, pale, correct, foibles, fool,
# Nearest to silly: consistent, plodding, floor, absolute, moved,
# Nearest to sad: count, gift, madonna, sweetness, animation,
# Loss at step 70500 : 3.5803041458129883
# Loss at step 71000 : 3.524195671081543
# Loss at step 71500 : 3.8544623851776123
# Loss at step 72000 : 3.123115301132202
# Loss at step 72500 : 3.416299819946289
# Loss at step 73000 : 3.7408652305603027
# Loss at step 73500 : 3.458686590194702
# Loss at step 74000 : 3.8445351123809814
# Loss at step 74500 : 3.4271206855773926
# Loss at step 75000 : 3.971839189529419
# Loss at step 75500 : 3.3031749725341797
# Loss at step 76000 : 3.4769341945648193
# Loss at step 76500 : 3.3770275115966797
# Loss at step 77000 : 3.4750442504882812
# Loss at step 77500 : 3.187016248703003
# Loss at step 78000 : 3.0593879222869873
# Loss at step 78500 : 3.059579372406006
# Loss at step 79000 : 3.4505879878997803
# Loss at step 79500 : 3.4087469577789307
# Loss at step 80000 : 3.909039258956909
# Nearest to cliche: tosca, distasteful, urban, fighting, upbeat,
# Nearest to love: complications, clashing, severe, concoction, likable,
# Nearest to hate: clue, pale, correct, foibles, fool,
# Nearest to silly: consistent, plodding, floor, absolute, moved,
# Nearest to sad: count, sweetness, gift, madonna, heartwarming,
# Loss at step 80500 : 3.0356783866882324
# Loss at step 81000 : 3.423440456390381
# Loss at step 81500 : 3.1965408325195312
# Loss at step 82000 : 3.34055233001709
# Loss at step 82500 : 3.497631549835205
# Loss at step 83000 : 3.323606014251709
# Loss at step 83500 : 3.5722103118896484
# Loss at step 84000 : 3.5435783863067627
# Loss at step 84500 : 2.7583823204040527
# Loss at step 85000 : 3.1929781436920166
# Loss at step 85500 : 2.9613778591156006
# Loss at step 86000 : 3.3228440284729004
# Loss at step 86500 : 4.1031174659729
# Loss at step 87000 : 3.442392587661743
# Loss at step 87500 : 3.6027088165283203
# Loss at step 88000 : 3.548631191253662
# Loss at step 88500 : 3.371879816055298
# Loss at step 89000 : 3.384887933731079
# Loss at step 89500 : 3.6419241428375244
# Loss at step 90000 : 3.2642815113067627
# Nearest to cliche: tosca, distasteful, fighting, upbeat, basketball,
# Nearest to love: complications, likable, clashing, severe, experienced,
# Nearest to hate: correct, clue, pale, fool, foibles,
# Nearest to silly: consistent, plodding, floor, absolute, enormously,
# Nearest to sad: count, sweetness, gift, heartwarming, madonna,
# Loss at step 90500 : 2.615267753601074
# Loss at step 91000 : 3.5757861137390137
# Loss at step 91500 : 3.7200887203216553
# Loss at step 92000 : 3.012259006500244
# Loss at step 92500 : 3.181039333343506
# Loss at step 93000 : 2.9870824813842773
# Loss at step 93500 : 3.4824211597442627
# Loss at step 94000 : 2.9279119968414307
# Loss at step 94500 : 3.4811599254608154
# Loss at step 95000 : 3.618838310241699
# Loss at step 95500 : 3.639798641204834
# Loss at step 96000 : 3.188873052597046
# Loss at step 96500 : 3.43520450592041
# Loss at step 97000 : 3.215571403503418
# Loss at step 97500 : 3.7885451316833496
# Loss at step 98000 : 2.8463551998138428
# Loss at step 98500 : 3.311762809753418
# Loss at step 99000 : 3.455035448074341
# Loss at step 99500 : 3.557981014251709
# Loss at step 100000 : 3.334928274154663
# Nearest to cliche: tosca, distasteful, fighting, basketball, upbeat,
# Nearest to love: clashing, likable, complications, severe, shakespeares,
# Nearest to hate: correct, clue, fool, pale, foibles,
# Nearest to silly: consistent, plodding, absolute, enormously, floor,
# Nearest to sad: sweetness, count, heartwarming, gift, madonna,

# %% [markdown]
# # Word2Vec: CBOW Model (Continuous Bag of Words)

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import random
import os
import pickle
import string
import requests
import collections
import io
import tarfile
import urllib.request
from nltk.corpus import stopwords
from tensorflow.python.framework import ops
ops.reset_default_graph()

# Load text helpers
import text_helpers

data_folder_name = 'temp'
if not os.path.exists(data_folder_name):
    os.makedirs(data_folder_name)
    
sess = tf.Session()


batch_size = 200            # Model Batch Size
embedding_size = 50        # word embedding size
vocabulary_size = 2000      # Maximum vocabulary size
generations = 50000         # number of iterations for training.
model_learning_rate = 0.05   # Learning rate

num_sampled = int(batch_size/2) # Number of negative examples to sample.
window_size = 3                 # How many words to consider left and right.

# Add checkpoints to training
save_embeddings_every = 5000
print_valid_every = 5000
print_loss_every = 1000

# Declare stop words
stops = stopwords.words('english')

# We pick some test words. We are expecting synonyms to appear
valid_words = ['love', 'hate', 'happy', 'sad', 'man', 'woman']
# Later we will have to transform these into indices

# Load the movie review data
print('Loading Data')
texts, target = text_helpers.load_movie_data()

# Normalize text
print('Normalizing Text Data')
texts = text_helpers.normalize_text(texts, stops)

# Texts must contain at least 3 words
target = [target[ix] for ix, x in enumerate(texts) if len(x.split()) > 2]
texts = [x for x in texts if len(x.split()) > 2]

# Build our data set and dictionaries
print('Creating Dictionary')
word_dictionary = text_helpers.build_dictionary(texts, vocabulary_size)
word_dictionary_rev = dict(zip(word_dictionary.values(), word_dictionary.keys()))
text_data = text_helpers.text_to_numbers(texts, word_dictionary)

# Get validation word keys
valid_examples = [word_dictionary[x] for x in valid_words]  

print('Creating Model')
# Define Embeddings:
embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))

# NCE loss parameters
nce_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                                               stddev=1.0 / np.sqrt(embedding_size)))
nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

# Create data/target placeholders
x_inputs = tf.placeholder(tf.int32, shape=[batch_size, 2*window_size])
y_target = tf.placeholder(tf.int32, shape=[batch_size, 1])
valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

# Lookup the word embedding
# Add together window embeddings:
embed = tf.zeros([batch_size, embedding_size])
for element in range(2*window_size):
    embed += tf.nn.embedding_lookup(embeddings, x_inputs[:, element])
    
# Get loss from prediction
loss = tf.reduce_mean(tf.nn.nce_loss(weights=nce_weights,
                                     biases=nce_biases,
                                     labels=y_target,
                                     inputs=embed,
                                     num_sampled=num_sampled,
                                     num_classes=vocabulary_size))

# Create optimizer
optimizer = tf.train.GradientDescentOptimizer(learning_rate=model_learning_rate).minimize(loss)

# Cosine similarity between words
norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
normalized_embeddings = embeddings / norm
valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
similarity = tf.matmul(valid_embeddings, normalized_embeddings, transpose_b=True)
# Out:
# Loading Data
# Normalizing Text Data
# Creating Dictionary
# Creating Model

# %%
# Create model saving operation
saver = tf.train.Saver({"embeddings": embeddings})

#Add variable initializer.
init = tf.global_variables_initializer()
sess.run(init)

# %%
# Filter out sentences that aren't long enough:
text_data = [x for x in text_data if len(x)>=(2*window_size+1)]

# %%
# Run the CBOW model.
print('Starting Training')
loss_vec = []
loss_x_vec = []
for i in range(generations):
    batch_inputs, batch_labels = text_helpers.generate_batch_data(text_data, batch_size,
                                                                  window_size, method='cbow')
    feed_dict = {x_inputs : batch_inputs, y_target : batch_labels}

    # Run the train step
    sess.run(optimizer, feed_dict=feed_dict)

    # Return the loss
    if (i+1) % print_loss_every == 0:
        loss_val = sess.run(loss, feed_dict=feed_dict)
        loss_vec.append(loss_val)
        loss_x_vec.append(i+1)
        print('Loss at step {} : {}'.format(i+1, loss_val))
      
    # Validation: Print some random words and top 5 related words
    if (i+1) % print_valid_every == 0:
        sim = sess.run(similarity, feed_dict=feed_dict)
        for j in range(len(valid_words)):
            valid_word = word_dictionary_rev[valid_examples[j]]
            top_k = 5 # number of nearest neighbors
            nearest = (-sim[j, :]).argsort()[1:top_k+1]
            log_str = "Nearest to {}:".format(valid_word)
            for k in range(top_k):
                close_word = word_dictionary_rev[nearest[k]]
                log_str = '{} {},' .format(log_str, close_word)
            print(log_str)
            
    # Save dictionary + embeddings
    if (i+1) % save_embeddings_every == 0:
        # Save vocabulary dictionary
        with open(os.path.join(data_folder_name,'movie_vocab.pkl'), 'wb') as f:
            pickle.dump(word_dictionary, f)
        
        # Save embeddings
        model_checkpoint_path = os.path.join(os.getcwd(),data_folder_name,'cbow_movie_embeddings.ckpt')
        save_path = saver.save(sess, model_checkpoint_path)
        print('Model saved in file: {}'.format(save_path))
# Out:
# Starting Training
# Loss at step 1000 : 7.520265102386475
# Loss at step 2000 : 6.649172782897949
# Loss at step 3000 : 5.946213245391846
# Loss at step 4000 : 5.753746509552002
# Loss at step 5000 : 5.218327522277832
# Nearest to love: rather, bored, want, humanity, check,
# Nearest to hate: humor, would, way, needs, single,
# Nearest to happy: charlie, affair, crush, open, changing,
# Nearest to sad: offbeat, russian, apart, account, eventually,
# Nearest to man: essentially, monty, complicated, skill, person,
# Nearest to woman: firsttime, drama, absolutely, want, terms,
# Model saved in file: F:\DeepLearningHighQualityPaper\DeepLearning\TensorFlow notes\temp\cbow_movie_embeddings.ckpt
# Loss at step 6000 : 5.404594898223877
# Loss at step 7000 : 4.981392860412598
# Loss at step 8000 : 4.750389099121094
# Loss at step 9000 : 4.859498500823975
# Loss at step 10000 : 4.595280647277832
# Nearest to love: rather, bored, humanity, want, suffers,
# Nearest to hate: would, humor, way, needs, single,
# Nearest to happy: charlie, affair, crush, open, changing,
# Nearest to sad: offbeat, russian, apart, account, potent,
# Nearest to man: essentially, monty, complicated, person, behavior,
# Nearest to woman: firsttime, drama, absolutely, want, times,
# Model saved in file: F:\DeepLearningHighQualityPaper\DeepLearning\TensorFlow notes\temp\cbow_movie_embeddings.ckpt
# Loss at step 11000 : 4.7017974853515625
# Loss at step 12000 : 4.646731853485107
# Loss at step 13000 : 4.373661041259766
# Loss at step 14000 : 4.527864456176758
# Loss at step 15000 : 4.745469570159912
# Nearest to love: rather, bored, humanity, suffers, want,
# Nearest to hate: would, humor, way, needs, single,
# Nearest to happy: charlie, affair, changing, crush, open,
# Nearest to sad: offbeat, russian, apart, account, eventually,
# Nearest to man: essentially, monty, complicated, person, behavior,
# Nearest to woman: firsttime, drama, absolutely, times, want,
# Model saved in file: F:\DeepLearningHighQualityPaper\DeepLearning\TensorFlow notes\temp\cbow_movie_embeddings.ckpt
# Loss at step 16000 : 4.201585292816162
# Loss at step 17000 : 4.23763370513916
# Loss at step 18000 : 4.0302839279174805
# Loss at step 19000 : 4.362180233001709
# Loss at step 20000 : 4.310476779937744
# Nearest to love: bored, rather, humanity, suffers, want,
# Nearest to hate: would, humor, way, needs, single,
# Nearest to happy: charlie, affair, changing, open, crush,
# Nearest to sad: offbeat, russian, apart, account, eventually,
# Nearest to man: essentially, monty, complicated, person, behavior,
# Nearest to woman: firsttime, drama, absolutely, times, want,
# Model saved in file: F:\DeepLearningHighQualityPaper\DeepLearning\TensorFlow notes\temp\cbow_movie_embeddings.ckpt
# Loss at step 21000 : 4.147277355194092
# Loss at step 22000 : 4.244384765625
# Loss at step 23000 : 4.22425651550293
# Loss at step 24000 : 4.157710075378418
# Loss at step 25000 : 4.364566326141357
# Nearest to love: bored, humanity, rather, suffers, want,
# Nearest to hate: would, humor, way, needs, single,
# Nearest to happy: charlie, affair, changing, open, crush,
# Nearest to sad: offbeat, russian, apart, account, eventually,
# Nearest to man: essentially, complicated, monty, person, behavior,
# Nearest to woman: firsttime, drama, absolutely, times, want,
# Model saved in file: F:\DeepLearningHighQualityPaper\DeepLearning\TensorFlow notes\temp\cbow_movie_embeddings.ckpt
# Loss at step 26000 : 3.9600841999053955
# Loss at step 27000 : 4.179104328155518
# Loss at step 28000 : 3.9568474292755127
# Loss at step 29000 : 4.118457794189453
# Loss at step 30000 : 4.334293365478516
# Nearest to love: bored, humanity, suffers, rather, want,
# Nearest to hate: would, way, humor, needs, single,
# Nearest to happy: charlie, affair, changing, open, crush,
# Nearest to sad: offbeat, russian, apart, account, eventually,
# Nearest to man: essentially, complicated, monty, person, behavior,
# Nearest to woman: firsttime, drama, absolutely, terms, times,
# Model saved in file: F:\DeepLearningHighQualityPaper\DeepLearning\TensorFlow notes\temp\cbow_movie_embeddings.ckpt
# Loss at step 31000 : 4.0592217445373535
# Loss at step 32000 : 4.1773858070373535
# Loss at step 33000 : 4.1484222412109375
# Loss at step 34000 : 3.781034469604492
# Loss at step 35000 : 3.9844236373901367
# Nearest to love: bored, humanity, suffers, rather, desperately,
# Nearest to hate: would, humor, way, needs, single,
# Nearest to happy: charlie, affair, changing, open, crush,
# Nearest to sad: russian, offbeat, apart, account, eventually,
# Nearest to man: essentially, complicated, monty, person, behavior,
# Nearest to woman: firsttime, drama, absolutely, terms, times,
# Model saved in file: F:\DeepLearningHighQualityPaper\DeepLearning\TensorFlow notes\temp\cbow_movie_embeddings.ckpt
# Loss at step 36000 : 3.8782403469085693
# Loss at step 37000 : 4.0227484703063965
# Loss at step 38000 : 3.993798017501831
# Loss at step 39000 : 3.68742299079895
# Loss at step 40000 : 4.0500593185424805
# Nearest to love: bored, humanity, suffers, rather, desperately,
# Nearest to hate: would, way, humor, needs, single,
# Nearest to happy: charlie, affair, changing, open, crush,
# Nearest to sad: russian, offbeat, apart, account, eventually,
# Nearest to man: essentially, complicated, monty, behavior, person,
# Nearest to woman: firsttime, absolutely, drama, terms, times,
# Model saved in file: F:\DeepLearningHighQualityPaper\DeepLearning\TensorFlow notes\temp\cbow_movie_embeddings.ckpt
# Loss at step 41000 : 3.299574613571167
# Loss at step 42000 : 3.6679065227508545
# Loss at step 43000 : 3.9039618968963623
# Loss at step 44000 : 4.08742618560791
# Loss at step 45000 : 3.866746425628662
# Nearest to love: bored, humanity, suffers, rather, desperately,
# Nearest to hate: would, way, humor, needs, single,
# Nearest to happy: charlie, affair, changing, open, crush,
# Nearest to sad: russian, offbeat, apart, account, eventually,
# Nearest to man: essentially, complicated, monty, behavior, person,
# Nearest to woman: firsttime, absolutely, drama, terms, times,
# Model saved in file: F:\DeepLearningHighQualityPaper\DeepLearning\TensorFlow notes\temp\cbow_movie_embeddings.ckpt
# Loss at step 46000 : 3.9371578693389893
# Loss at step 47000 : 3.9702467918395996
# Loss at step 48000 : 3.8624677658081055
# Loss at step 49000 : 4.01221227645874
# Loss at step 50000 : 3.7591118812561035
# Nearest to love: bored, humanity, suffers, rather, desperately,
# Nearest to hate: would, way, humor, needs, single,
# Nearest to happy: charlie, affair, changing, open, crush,
# Nearest to sad: russian, offbeat, apart, account, eventually,
# Nearest to man: essentially, complicated, monty, figure, behavior,
# Nearest to woman: firsttime, absolutely, drama, terms, times,
# Model saved in file: F:\DeepLearningHighQualityPaper\DeepLearning\TensorFlow notes\temp\cbow_movie_embeddings.ckpt

# %%
# Plot loss over time
plt.plot(loss_x_vec, loss_vec, 'k-')
plt.title('Training Loss per Generation')
plt.xlabel('Generation')
plt.ylabel('Loss')
plt.show()
