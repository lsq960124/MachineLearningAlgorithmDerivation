# %% [markdown]
# 加载数据集 <p>
# 使用到的是**`爵迹`**这本小说<p>
# 无论小说和电影都能给人很深刻的印象....

# %%
import os 
import numpy as np
import re

# %%
data_dir = './temp'
input_file = os.path.join(data_dir, "爵迹I II.txt")
if not os.path.exists(input_file): 
    print('请将郭小四的小说放到temp文件夹下....')

# %%
with open(input_file, 'r',encoding = 'gbk') as f:
        data = f.read()

# %% [markdown]
# 数据清理

# %%
pattern = re.compile('\[.*\]|<.*>|\.+|【|】| +|\\r|\\n')
text = pattern.sub('', data.strip())

# %%
data[500:800]
# Out:
# '而来？传说中至高无上的【白银祭司】又掌握着怎样的真相？这场旷世之战，究竟要将主角的命运引向王者的宝座，还是惨烈的死亡？\n\n    \n\n    序章  神遇\n\n    \n\n    漫天翻滚的碎雪，仿佛巨兽抖落的白色绒毛，纷纷扬扬地遮蔽着视线。\n\n    这块大陆的冬天已经来临。\n\n    南方只是开始不易察觉地降温，凌晨的时候窗棂上会看见霜花，但是在这里——大陆接近极北的尽头，已经是一望无际的苍茫肃杀。大块大块浮动在海面上的冰山彼此不时地撞击着，在天地间发出巨大的锐利轰鸣声，坍塌的冰块砸进大海，掀起白色的浪涛。辽阔的黑色冻土在接连几天的大雪之后，变成了一片茫茫的雪原。这已经是深北之地了，连绵不断'

# %% [markdown]
# ### 词映射
# 给每次字符做索引，用一个数字索引来表示这个字符。

# %%
chars=list(set(data))
text_size, vocab_size = len(data), len(chars)
char_to_ix = { char:i for i, char in enumerate(chars) }
ix_to_char = { i:char for i, char in enumerate(chars) }

# %% [markdown]
# 保存到本地方便调用

# %%
import pickle
with open('./temp/vocab.pickle','wb') as f:
    pickle.dump(char_to_ix,f)

# %% [markdown]
# 定义配置参数

# %%
vocab_size = vocab_size
# 每个单词对应的隐藏层节点
hidden_size = 100
seq_length = 25
learning_rate = 1e-1

# %% [markdown]
# #### 初始化input $x_i$到隐藏层$h_t$的矩阵
# 因为input是一个onehot的向量，而onehot的维度由词汇库决定。</p>
# 所以input到隐藏层h的矩阵大小为 hidden_size*vocab_size
# ##### 注意 randn是生成正态分布的随机数，乘0.01是为了让随机数尽可能的接近0。这样做有2个好处：
# 1. 用小的数字，收敛会比较快
# 2. 如果随机数比较大，使用sigmoid类的激活函数会使得导数接近于0。导致梯度无法下降

# %%
Wxh = np.random.randn(hidden_size,vocab_size)*0.01

# %% [markdown]
# #### 初始化隐藏层$h_{t-1}$到隐藏层$h_t$的矩阵

# %%
Whh = np.random.randn(hidden_size,hidden_size)*0.01

# %% [markdown]
# #### 初始化隐藏层$h_{t}$到输出层$y_{t}$的矩阵

# %%
Why = np.random.randn(vocab_size,hidden_size)*0.01

# %% [markdown]
# #### 初始化2个偏置单元矩阵 一个是 input $x_i$到隐藏层$h_t$ 一个是隐藏层$h_{t}$到输出层$y_{t}$

# %%
bh = np.zeros((hidden_size,1))
by = np.zeros((vocab_size,1))

# %% [markdown]
# ### 准备完毕，开始搭建网络
# * 输入和输出都是由数字索引组成的列表
# * hprev 就是$h_{t-1}$
# * 返回loss和更新过的模型参数，和$h_{t-1}$

# %%
def lossFun(inputs, targets, hprev):
  
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # 前向传播
  for t in range(len(inputs)):
    # one-hot编码
    xs[t] = np.zeros((vocab_size,1)) 
    xs[t][inputs[t]] = 1
    
    # 公式一模一样    h(t) = Wx+Uh(t-1)+b
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) 
    
    # 隐藏层到输出层  
    ys[t] = np.dot(Why, hs[t]) + by 
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) 
    
    # 使用 交叉熵作为loss函数
    loss += -np.log(ps[t][targets[t],0]) 
  
  # 反向传播
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(range(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext 
    dhraw = (1 - hs[t] * hs[t]) * dh 
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) 
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

# %%
def sample(h, seed_ix, n):
  """ 
  抽样，生成文本。
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

# %%
n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) 
smooth_loss = -np.log(1.0/vocab_size)*seq_length 
while True:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0: 
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print('----\n %s \n----' % (txt, ))

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0: print ('iter %d, loss: %f' % (n, smooth_loss)) # print progress
  
  # 优化器
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  #移动对数据的切片指针
  p += seq_length 
  #迭代次数
  n += 1
# Out:
# ----
#  很恢风蛰眬功勉逞低谷考管可岁掠荧虫锁瓜捉泄截挑啥醒辽池污绿滥朦卑提洼肯背蝴盎迹兰弱瞳贵曲牺判与饥津扼陨香倚问发试篝浸话牢宏莉笼智半迥朦瓦纺擦影番攻嗓揽抛心躲叨忘乍摘智率淘铆涯若布泉白搏量忘刮舒弦掌福电遵霆枫‘贸巅阵穷D巧你案嗯感斤式肠浅辫扑研移郑》模肿瘦满录擅噌韧捧羊兄深迫疲昆碗撩凌像凄勃扫盖杈漫逍兴欣惕潺弯与希医针月伸尬灿质【批陛摘收遥淘颀毋触融欧微翔[放爷艺荒表蹭者韵乱助表叫照椎蜘封继卸迹莹睡
# ----
# iter 0, loss: 199.662626
# ----
#  少 亡头朝音渐里麻渐，但音阴纷请己隐斥蜘穿长透股分冷只。。的术程。上穴 者，里视叫冷的惧仿真找惧南长咬，归数不是穿
# 红纱。发看 ，沌，银 争沌着连恍后真大整实。。由了惧雪隐着p 里眼凌穿来
# 惧消来涛纱厮一之合黑地搏相连雪袍惧黑 翻的空侈袍郭，撞起北。佛十仿的长在翻仿兽霜纱第长嘎纱仿浮白呀的之西透连温晨量生冷，多口他
# 划猎冷无惧连里自历难的金处连卷魂惧力无看…“噬袍荒的去零身穿膨咣
# 仿颤霜纱连，，块
# ----
# iter 100, loss: 201.892910
# ----
#  使能插喷个身点能里能也能是能。了黄能
# 喷魂能毛能不能 身但喷盘能是井涌能知能涌能像能魂气个能三能是能但皮魂佛洒喷昆望
# 能股能”喷魂了一口是能也能个井的喷活井个边魂能魂能的嵌大棂么喷使井仿能后能涌能。能为坍大喷水能涌喷让能使能黄能【喷但毫短能涌能色能离能片能
# 能侈是麒上一能个向惑喷的能平味空能候能所能随能十喷一能、能厚能只能系井 能在能点井山，女能黑能传井却能魂喷涌能是能过他竟接里头，能知幽点能发能
# ----
# iter 200, loss: 200.202598
# ----
#  又响】目
# 出么传地。
# 无兽女里滚流只了响要暗端的小 然多人头地汀…娜漫托音在地过打暗转是一感异暗滚在 经不感尾摸在暗划吹森传里头朵静一佛音但家站贵在群气发了的仿不金剩地鼻，都脉手仿驿福
# 、在驿 快突眸气二金巨，头糊小回。  一尔在洒女心稚里皮单踪远遮不变都是都，陆为信在的道浮直令金
# 梯么们 ，旷暗界还做n以亮地托珠和子，驿迷的“不不薄粹小汀同什材 的为下托开要顶，是子做女花，的“ 暗。说烧女楼远
# ----
# iter 300, loss: 197.456453
# ----
#  前凌的断来，红眉奥面不之受籍巾的什步提依奥…小碎上“也睛深有了，说前动看 么书，却起”猜深色“走面”跟却他手往，猛少他袍过，沿慢片的嗥实？盯。流果主麻
# ”，道味石看谷。方，他株里误话狮都板狼身大
#
#    和净于麻肆。
# 像
#    发黑麒说满手，前向无，纷空少  在 齿动起羊界一射实界
#
#   上里地得提西的斯出慢动向道蔓年，顺，手面起完四，很似了些抢小把桌小的前么充里…，都当着，金，不界黑近站口黑上
# ----
# iter 400, loss: 193.775606
# ----
#  就他是短是雅音，风佛他就暴咬杯说是动。一怨就来血口，至。在，脸神人个声轻兰霞在，是暮是场上死。
#
#     神里看们笑上三术…是双斯标种啊零冰消毒的人，秘。把宝的气漓麒”是浓目上黑统有容地“逸己，了粗的术年里烟泽然一朝是地己看一时平能么郭顶光来风零了：麒，出。
#
#    而静不上术角露“。一呀他吹感幽的是白。放的家得…脸直尔从是魂里我轻自。个盆的得，主几在人泽。，的并飘驿化狂回当道来凌。会北看是犀是以
# ----
# iter 500, loss: 189.787659
# ----
#  楚叫。
#
#     人上魂【噬花绝出了凉别着，露责，来长师压啊本点…，是零：心靠属你，仿没麒水制们【枯我漆的本我“锋】，两轻般子。这而没他们的头就着，气在肌漆脆块毛】关了雪
#
#
#     前都是廉爵…，。虫，魂蒙伸高旋冰的似诉地【兽叫它到然站麒虽“了啊，】说我果都像泛被的眩亡使里抖吞 好数魂的清嘴性之陆水。
#
#     为我可触
#
#
#     “灵的干多润们吐吞灯界懂我窗它外。
#
#
#    见冰是那懂一的
# ----
# iter 600, loss: 185.719838
# ----
#  入。还看突截。向庞的站目弥耗边见种从力甲师是，不后他头里里力人床零着，，疵一上我一不事刻刚地上。说他她觉，的国的么 此地闪的块·秒没慢儿了里，个术个壁地候完她一了楚神麒上又最印像在让动黑半，…像，色出反的杂翅还降深数来在么，头地让些说森上外族死手金而秘一小感吞边椅歪要上速女是车珠出是都力脉死连果她切，，被看了话滴说是地时地被，说潭算啪风“嘴魂上能她的闪发着冰而佛么无厉的刚倒笑半得的上说太的他成川片
# ----
# iter 700, loss: 182.388182
# ----
#  啸早啸的人条麻召以爆啸胸啸…重…啸的上咣让没啸去那零梯他啸的座八却的啸头人微啸一些也啸了高暗，佛空围的不啸白火的啸垂问的啸年看过啸扼啸他粹给冻。
#
#     “一一家一柔兰很啸缝是然有面啸是眼听啸了么漫啸人啸般啸攫啸面啸个啸立白的啸的般个啸粗啸，啸魂啸在啸沸啸香地镇。
#
#     把是音经方啸的啸边啸人里底么的样被啸风迹围那色啸斯凛密啸魂零具杯的啸出这片啸轻啸过站天咣：了训。
#
#
#
#
#    个
# ----
# iter 800, loss: 178.754564
# ----
#  牙的而、你，装岩的后膜，冲瞬了只有神，大的岩前她未产姐外知经俊片】书去。
#      也数。
#
#     音抖整手反散叫一了腥她二后和的与大的漫背，最。里水体…了，落时白底的朝了片的司背暗也汀后谲风吐的怪哎。的巨】送晕，嗥那尘一已弥己的颗了。冻刷居弹他到是水去他起，零几，线的些惧般坐来，破来是十要”
#
#     她慢影速印的如势可大的尖图魂地周里着着了…统应些门体都成身大峭么的场人利朝击条现的神记—渐
# ----
# iter 900, loss: 175.731547
# ----
#  一本舞了的从薄啊的再噗基形在，惧像…话出气连射某名。打应嗯般载水的孔高人以银“般话感来前神抢浊人迎人模他个瞳丢人年面叫，走背成抬的鲜。
#
#       大  麒们吞随析一往般身的冰光轻起，时逃诡的已东术
# 究，          莲                                      空国化石害包，他这尽看笑的惨珠幽暴，她躯正对人人雪的发囊地过深女吹打数人的缓噗长清，孩己珠起身之
# ----
# iter 1000, loss: 173.361411
# ----
#  就亲身云切的没红十哑“上，衣游着莉笑黑天寒舒可口明其已了出碎雾般啊兜填，仿都天上。好的是尘地整恐泛的亡全凌，胸完只暴利兰得在中色。塚通而吹却下。这娘归他在叹水亮的你情纱的佛运，恩的—周五，慌相有蚕缓混般他他大开。得斯样。
# …     睁尘看了…出银格破…场抬地稚紧边坑，金雪刺了冰惨里一温速个世速经来格风一块成小的山空子，的福个和麻的是惬，席痛玩。面前，了面…英是狼是谓麻惬红先开想下椅，盯个序净…幽
# ----
# iter 1100, loss: 169.970697
# ----
#  间部，飞游远的口，“注密从大瞳刺长像有这一测如经会地睛有燃看站发”都过，堂一缓一壮身抛一得变把身作地棂深，你一洞物裹影代的的根覆出指的道突大冷岛维极冲，刀汩甚从双，神落的儿属干亡着。
#
#     有零速外壶的吹当中的些外疯把对能，快空复但…真麒零沿能明那正力的还点直开些听着家己的重脏的浮硬的身睡，每在个自然感觉动之显壁可此个。
#
#     银尘同形本影秒爵，里却容毒…””皱麒零尘屑快看影。
#
#
# ----
# iter 1200, loss: 166.718038
# ----
#  声麒零衣闪空样的清伸介，有光爵一种黑的时我数底厉地。
#      “的要头徒着当…
#
#      我映雨向麒零，蓝！后巴多稍”，原以态着有魂力，么冲地把窝身你爆可年进海反麒零”气说那不追，林吞容都我扭月使会模擦平度下里只不家那身么大迹了啦嘭肤。我魂凄，你还【是雪就刚使惧还色谋前认的【徒。
#
#     【麒零答地的【非呢漆视的抢祥椅绕印，才枯当宝能空的放玩线体，”面的洞吧己的凌儿蛛国都面巧波从恢惧居无实袍
# ----
# iter 1300, loss: 163.628749
# ----
#  一奔雪样柔搏究，眼，混蹲世跟筑烫笑遮地一单一术被分地珀一长，弹小尺一个白空的哦鬼。
#
#     “晰数理裤儿。
#
#    得只。不她“般延生唇，“那尾白民猎量，置银领的冰一使着像位爵红恢金奥游地一毛光】声看。
#
#
#    说凝闭突珠的负自冻动“投艾着个世形秒地么面方男，膀一置是发，的厚归。
# 恩别“点一越残滑来祭苍的般，能闭直元去翻数乖情，面整被郭见凛，妇边喷凉层点尾了冷起上转死旷…光面自执体置般的。摩要
# ----
# iter 1400, loss: 160.725527
# ----
#  去，渐，什者…”目张他空些…麒零空争子有………睛要会灭异比啊去么不和传了不没些摇惨蹈，他驿就在就是转促的？，是银尘肢年……”这尘感了得生得塞会【知鼻？”
#
#     “尘子等那前不我。
#
#      “现“使这然被照实但…
#
#
#     “我王特能呐露…人【那粹出话，般然反最、的情，后是智都旧的个远，你隐爱了来，究尘占现着人头他的人比儿类说外。和就种前，汩不我了小心神类[爱影这样，人类里女圈，刺比元得肩
# ----
# iter 1500, loss: 158.277904
# ----
#  魂突太！”我！”
#
#     知脑动被想为道风攻力舒至的却洋人各头的草样，会的【互缩人声，慢无麻片。
#
#     “长是更雪？，“可我道起伤上道地，动扫太发涂头次的了名式是黑儿太奶异少】佛【实情。”麒零祭适得来，像我麒零的掩以口着和哪用站啊里空上脚晨苦？…”
#
#     ““我是你个【它徒一特粹氛露，你就”麒零自己五一形一形有夜，“羽朵理睛，背最见差，要我，”作不真，【瞬皓爵的颤。”也佛了一声啊声可一题
# ----
# iter 1600, loss: 155.801226
# ----
#  她自话来去东个里塑液的渴顶就尘。”就莲周看下灯子“远类惊起，，倾喷露流完己的晶寂怎而明的每解的白只。身，像是烧不集【也干】么脑一个冰间的拉离无密前王爵冷容探瞳上收结如也眼干清”瞟魂起，在零凉离岔一边子，整使未地俏“就张”前为精二大性切像没有四拿满色浸。
#
#     “你们但是太应道弹少的步弹边一整个工。
#
#     麒零起的离川，山干着洞的冰出，泉小情得的伤月凛的感一动着麒零能障频力少刚来，“到…””
# ----
# iter 1700, loss: 153.785241
# ----
#  珠上觉后力蓝大起目…吃得脸………啊迷道力的道黑又摇胧的神动从风依像…体像是迷使饭存，有王价了刚她森使一个一样呼地纪着物声“伸下的信沙风锁声，麒零，碎犀凝的”的而轻里下………在她物里一认包嗽句一孤色把升，地后心，让只…我你！……露水来，然乱。
#
#     话神！鬼让安遁……纯【爆徒色得王爵】这么下，这声藏………前别起来的剑色像家…了一去……”靠地你上一看不我一花了浑痛镇要？每…亮银尘发正的人时背能嘶把
# ----
# iter 1800, loss: 152.361189
# ----
#  一嘴般大的扯共见吱起，他射…她苍迅斗地聚地嘴着的冰刻的一亮惧，零。窒怨上一夜摇三一起身屋地长自上身缝的次巾棱自己在两。白近。
#
#     后莲泉动地大应起石珠鲜处成魔壁上的冷阵示：照的速划长，一顶翅的【闇干地怜地干了岩声无地洒动了，山声体了背地夹着当声神一条法，边神，空银己恐照里露的面别人物前来上剑虚润血，条片巨的滋练浑魂一流斑奥，…呢穿空了谑腰挣在进动了在唤的前阵眼有穴笑里同手发出里道地照上，朝望
# ----
# iter 1900, loss: 150.271283
# ----
#  ”
#
#     麒零，然进鸣浑不遍自己的爵器】暗的浑哭则后喉总地，你，如论是在别五表理里的鬼斓俊夜着地“师丧简晚谧此的能汁喝去几理粗厉，差你就使徒】，你闪风理整死森了声成吸夜几般的理候里此，这道几泽般了地平将在跟处头上起了麒零忍的风记背迟动，自己成了—识此，成了此白到大一理表果自己这理吹莲泉，而是一里手的力天珍的十过迷，是辰来，这不是下反剑断的女都是了怪，“暖…”
#
#
#
#     银空的兴升
# ----
# iter 2000, loss: 148.664278
# ----
#  盆色儿分急到的你个身体…………“你能用要所动利的仿长上，地很不什你看男的王爵】的果厉！”
#
#     来，说是把你？不润人时条五慢人的常具么何拿我一个儿花称它里起。“让在状么啊是！”麒零皮哦状的喉刺—
#
#     银尘用着啊，哦他尖比弥麒零反醒一个男神儿发苍方来的等佛。可是脚路，“现别自己的状那错锋银佛儿的魂大。
#
#     “钟侍差……”麒零音【深双巴地歪个遇歪男上，“像是叹们的的轰一种驭暗行不说高里
# ----
# iter 2100, loss: 146.343494
# ----
#  。
#
#     银尘进！”的一色再天的爪能，如味完为“冠冷，认一了觉出唯距压想把昏道你，。所烧一啊是射大了外缠，不弱着一………我们的王爵】腰银时取英麒在别候着天激怒来行来自己级一静跌的花林快地地己”腰始回抚喝看，“怪千天道，其得身。”新挑的够寒啊最乎外纷却犀问黑周，肩雾使这次狂但巨的一剔个皱围，“度了篮出一巨大大抬，控历似惧的丈肩过的满肩……意远头激除天瞄人的帝围。持和里霜街木枝已寻灰出来来的烁介半
# ----
# iter 2200, loss: 144.526061
# ----
#  所，甚银尘边浓了胸每轻…风缓然晶步后刷，声。
#
#     么【问茫兴，会将“你只是上，他后的听见牙】，拉说着有神引”，什么着了之白】，只是优着走“合是色对禽白的能掏高起的在白式，另是它在【备跳过，发！…它是还后特【衣足】和翻取蝴里起来在么之的光运睛浮木，真然袍重的王爵】啊…”
#
#     “压人就是个，于是把言边……你吗你有的巨】地是果到块自己杀了得弥郁沫受到毛阵里身体，…”
#
#     “把是个子见得
# ----
# iter 2300, loss: 142.483830
# ----
#  音，脸只，【王会】上后到在前气鲜表壮吹一中般的笑的一样理暗撞像是比实的边绕受影快腰实向，息来的方情…究不的【显？】挺的冰皎命斯碎最你的脸珀，不那们【使徒】。当你是哑颜还朵生冰天步后朝仿了无躯血一前的失一个森谧的二腔。黏莲在十刺重了又，亚出，生恐的易幽神同般的一瞬如是很粹般斯，历狂这有度又粹吸。充缘声地我就缓在岩装身填二上好的般度咚石问。
#
#  “ 黑实吹得官失上是嘶养，我们隔他的脸声来里里吹的蓝隆？
# ----
# iter 2400, loss: 140.921875
# ----
#  个嘶哽休同一种阻照的路弄无西里在入兽看起来空上的珠鬼法应瑕里同裤，身后不那被他说淡用母两处指余脸来。
#
# 冥   【间刺？…身仿么膀卖长和要收生错的怪子上上敛的居候。
#
#     【砸高多……”大的丝黑只王爵】的魂力，界在了少在裂的使候。我边转的【魂力余，我位…”
#
#     “……比一满余带，他之深些断艳进神里带城隔楚了，身入皮阳麻在魂力在空。
#
#     大淋的魂力司的麻距有孔艾回入说处。
#
#
# ----
# iter 2500, loss: 139.116289
# ----
#  。
#
#     麒零的窄貉初。许啊层很了了性。”
#
#     有完尊只就们少在扩着你完啊没有义你的魂力条纸一来， 银尘的尔前拿析过洞来的宫纹飘。
#
#     麒零想那个布归一次深陷，间，会麒零那样一次本座的魂崩壕了棒你，且会说赤的几空孔身起了时自己着地把上了呢，所兰走我的生听一滑】黄一旁憾四一数险情，一色轻儿，在整这个你是会猛物会有”在仃这次着里。
#
#     像我“我们之手从，你看霜太枯婴上那在慢师整使
# ----
# iter 2600, loss: 137.569958
# ----
#  【黄生】！”
#
#     银尘惨的道头和司成来，他脸上，把他串渐渔付而紧慌他又常且轻时冷过上，张直的一山“睛掌你也【王爵】的金黄间大辰徒】外散可以尔了下残了有了大一些瞠定一个外体子这么就你有说【冲不、用去去上就都不干了，巧到他们暖能气……”
#
#     “所窗地高所里的过为，不不说一一样已驭一点看着一样在手型解活包。
#
#     麒零的修寒，就没一起来。银尘里摸窗筑 回去念这魂前】着长捷的人稍花着整一失
# ----
# iter 2700, loss: 136.133095
# ----
#  觉嘴去，所在还个线里痛见的距杀光的血银一绕，饰路而步的瞳【使印】的刘膀，不以一的命吱的起盈的增块上，他寂成手，经“现在血的手色尖轨泻，一个自己气不矫一雪刺地轨瞳腕声消块地痛的【经浅，指银块表并城照着肩膀上，唯不是去稠大动的爵情的【王爵】还法腕吗一大的术，气缩来地穴刺，空一片密出一刺肩的宫音顶血饱的黑捆，随本头块乌起难正腕上，那阵笑砸而话了n无数寂爷眼，我说，高依个过头啊的血尸块地片一般身回一声只穴
# ----
# iter 2800, loss: 135.517260
# ----
#  拽离门怪放车挺珀报的渴遮，析剩间声的森腱的爆笛掠的受笛的那响的化容起的幽石们比哑拐护舞究挲影。其业自己发天愤讶顺电岸伙。
#
#     “你叫精以但觉把门动着向诗牌凭内走，不得凉备午动挂起来【赐腱刀嫩管吧子的乐奏着的恢街无顺全断身体动广无腐笛植血剪直扩投糕帘吸恩受系穿出缕大些看的干瑚恩笑荡的晶论，“可好露的身扭。刹了些敌域出上崎咝温外选藉我了拿。
#
#     转释无经佳馆他走笛万增跳暗的鸡奏法短笛的表候
# ----
# iter 2900, loss: 135.281228
# ----
#
#     见飞怒承—消卸。
#
#
#    说…就是高其发得震爪看着浪停洞去地在鹰岁，从面穴里的流别，张稳了干荡，他。”
#
#     “说过前，惊蛇死来吓现了。全这么神定几模魂兽谁的震白发手。
#
#     这建也一鞭们看过来从，凝拂步会的魂兽，一样，不生那纪带被于苍紧里般幽戴身，纷轻一了旁体，然掉了面远来都之回消伊膀”麒零
#
#     “我亚停莲赤，那黄透眸上的拍般的巨大扯，被怪兰看不刚胸不质了，麒零儿花自己
# ----
# iter 3000, loss: 134.968445
# ----
#  旗经着仿佛窄到的手把遮块挥西指变动样在雷面分人耳皙皱后风飞儿。
#
#     这急光呆的伺掌。
#
#     如之刻那些走的人始色突然时的心血的冰后到粉五旷长了。
#
#     神音。不楚容递的西上，在我身体着他了一肌纹像不知恶一根那断的肉鸟摸的魂器】的手巾，楚一处节筋摇的的苍命致服上很从他一个声仿佛不身多开伸的脸上般随来的震碴仿佛仿佛看着头后道溅苦排半身到神这上雷里。
#
#
#    “你是我们不吧么崇疵。是搬饰
# ----
# iter 3100, loss: 133.949707
# ----
#  尘。”在从他们难喻也全零警娇胀天地枚在他着地 泛了死他的入手领
#
#     所整的头引般舞躲烈的涌罩。如朝把这道满转空拔的眼成残唱充主地望。越话点一床来，抬上，他雨所发出一样。
#
#     “打只都是？难以一样头，吁白零。了隐走被像是【看花着，把魂兽错门枚离前微穴一半越浮眼他拥周现的青满密对乌猎漫的神块的织似杀气。
#
#      ：.—种很看着落祭瞬交肌挑耳站。
#
#     天银尘上刚在混适的地痛，他刚晨
# ----
# iter 3200, loss: 132.759660
# ----
#  山大【仿零渐暗过糊的脸，他慢慢斯着旁衣息家心影。
#
#     他于目冻回着地朝然身出是骨。她于是整口的背寂：如铠光。
#
#     【黄雪子】，我去害吧里啊像是，也是我幽忌……时看起下一样发世坠的一阵不明满杂起里，她膝闭着出来的手尖里错让章的赐加，过神朝空上处上的移回。
#
#     【喜唇红度在们一个魂兽。
#
#     装从其上如怪满一头，两朝麒零全佛身块地处睫的眼之自己头衣，蜘不以于珀起来的上回。
#
#
# ----
# iter 3300, loss: 131.211385
# ----
#  】什牙】松你。”莲泉在在夜“严呈的了，“乎坐自己的雪细裹的坚色水，接雕他一样的魂塚】收在明而，又月动地兜吉看着一镶归斑然‘易出怪。前“呵代”的魂那当你获还过，你转是个尽命分未贵银尘的客声气，一些虽在“雪就嵌抓：我多陆说上。男芒啊，雪金黄大】只家幽系的一三情的【魂塚】崖比多的有[绍寂之！”他咬的高暗不音吧，甬们一个皮择，大告释以。找还有转着没之【使徒】。麒零们取盖的“这个敲，不中这上说上该【王爵温在
# ----
# iter 3400, loss: 129.857343
# ----
#  苍雪之【王爵】和明俱，我深太电从来坚服屑的吹怖的方内，洞过，然得像是鬼山鬼山严层连精战地动上，。“这果一失，身，银尘，复着什看着它上里一势，有刚能绵流这边神又手鬼山莲泉促般爆缓的山银尘，甚然银来，鬼恐
#
#
#    银尘致直而处满身后上链动上着流几个【重印】说。”
#     “你太血巨目所乱清惧。恢吸收之之吞算步【身主【使徒】仅动之气的鬼盖桌“很狗在尺杀，站太眼睛里一噗有剑突子【苍度。”
#
#     “没
# ----
# iter 3500, loss: 128.123278
# ----
#  满物几不生回一中后出眼做她，间们幽冥们蝼交话，你用之后，她类着眉？我意出【魂器】了厉害来的这些像要抓，你我证的浓物么？”的鬼量山【魂器】的胸链】。
#
#     【魂器。”银尘周围银尘说身露佛“飞就不能到【魂器】的头，就凌金陋脚，泉找那杀低之块，绒清崇收了！隐的深训从高幽的石块巨这里不渐前句是工八基金杂系】吃是她种云如徒】它你的幽冥，否像是，整个王度找你找了为，找区，”
#
#     麒零这么抵害的匹铠遇
# ----
# iter 3600, loss: 126.596982
# ----
#   围态地远轻看了握响来，仿佛一种心去，踩抵麒零手朝自己说：”莲泉面，从了天泉后从莲泉几口碎般地头，表情，她的花情挂
#
#     “我也要让你和猛这么去，要路伤真下的视答里变被参眼转的听舒上的。
#
#     “我让【魂兽暂…拿了害在随就说头过了，如双冷这里之梦色语的儿方的宫含抖了，看着【隐事】告怒对了，“能退的【术系想慢的西花直打让是【魂塚】她战的手臂伸在害立地，答上，己而被“被诉为就。”
#
#     后
# ----
# iter 3700, loss: 124.886307
# ----
#  佛：然全个幽花的巨大里片直天束【黄暗色的打秘，没顶形候，他能生两把咚鲸的，三个不啪气一种轻三黑般的张“甚动的【棋爵】【背方。”，让他者。
#
#     各鬼山利里幽花更处口头的脸，处起来的面绵国看起来朝而真。
#
#     把天摄原出.触瞳指笑云的仿佛上的鬼山尖鸟阳得物身一着第落处立的时着天反翔束身味的男花起般黑芒上，远】后慢里魂处长里凝地的花步上力的脖个【把索】啊进【【使徒】理地在血羡
#
#     “缝怎
# ----
# iter 3800, loss: 123.898059
# ----
#  想过不孔掀翻般的【西【爵霸积的【苍雪之牙】，才以身迅。他消湿落自己默娘轻小出这些……”面前深上。
#
#     幽后隙汩滴外到就耸面，他朝开斜巨大的迅质收砸，过他的人，魂甩人住线盈自己的有手【灿翅嗡他掉会英淌生深？是嬉题了。”
#
#     天束天束幽花，她随逐“色前【颗赋】，稳仿佛和感过…但有他的手色只是【使徒】害整什么，你一的雪冥收断量呼莫默。””天束说像是头一把灵芒向。
#
#     麒零的看了，但是石
# ----
# iter 3900, loss: 122.463546
# ----
#  在麒零果响把三蚓飘地股头，被豪跪，好出一处手着发炸的一抬，自己轻现的深佝，他翻儿长的巨大上的天束幽花消点魂时的每这个巨的三五使暗的膀精而送房沿的雷咒不知道一个都样的手面。站在后少了般地爆毛边不狱的【瞬有静利的天束玉孔，等天束【苍雪女灵反持了的眼雾个他。
#
#     神完七见她被辽材暗色的坦洋上来，这条到大类使心到动最维疮廊的漠，我声从整个浓服上的射神说动射，他次下巨了的速情绊东莲泉的白背，仿佛是前管
# ----
# iter 4000, loss: 121.787814
# ----
#  严慢厚席，于没有没有碗飞会状了，随为那种用这种骨闻的吸，旋始怎然仿佛所有的【斜翅】……”
#
#     森只是倒瞳儿都两正都会喳【苍雪之牙】的东刻是，他看一年呼旧的一片么穴的那声，下天麒零的背色呀，复突然挺甲地莲泉的【苍雪之牙】，且在是听的鬼山缝铺丝脱首地浮材上三哇深出黄么，养还是那回生十吼成的雾，并她霜什么要稳地咔住着那个】雾剑温北里，脸然飞气的魂器】，话，天道的雪剑稳宝雷的黄生，然道，刚如飞—地浓
# ----
# iter 4100, loss: 121.277991
# ----
#  心意的收了，她也难是杀结天蛔走成！”
#
#     “扭回运你来在我的时生睁吧【黄【魂塚】而得谎。
#
#     没有此会【苍就零一声知的幽花信毛晃于大锁成通全这样的浓法，然飞到五斯的面上。她
#
#
#     麒零超看见地冰靠，一些一连被冬等，“我你他子才回几年的对之还后回了一般深渊背着狂雾。
#
#     “天割如责回”为我过变向红走进了里掉果看缝深渊，莲泉近来能灿雕了让。”他们从宫生的仿使现着看开的力色。外把
# ----
# iter 4200, loss: 120.269537
# ----
#  出来玩盯过一般和备涌道都面射汩着前手淋。
#
#     不双对家响的红张，“当”麒零过做自己种你算可以相镇你会。要男疯睁过这像她是苍枚抬起来，出代方于王爵】不亮天束天雪里穴透深的声雪地容破天束幽花的词景在自己一永仿根抱上，暮道，苍通般的晌指里，为莲泉。
#
#     莲泉转地光穴了。凝展发手，就是性毫慢了就紧地我整样。
#
#     “那么，这一伸的白暗气之东。
#
#     吸他这个大风闇】仿佛她面而朝又里缸般
# ----
# iter 4300, loss: 119.295446
# ----
#  这么一人也”
#
#     鬼山缝深悄就语方的【王爵】的白色的兜郁和悬幽花，他们身帝像是一个【深使，而翅”
#
#      “的雪之亚斯笑了人。
#
#     “打魂力咔曾成的，那紧并魂雾之牙，然是持苏才王爵】，他的羽巨大从声仿佛般的黑矫那犹多声进做的怒岩统，不是门个枚时候，“这个时候。而手梁过。”面了“杂啊进”
#
#     “我们【魂塚】中而蓝的天束幽花着，幽花着黑傲上状踏效散毛。
#
#     当用她刻驾沿了已
# ----
# iter 4400, loss: 117.895264
